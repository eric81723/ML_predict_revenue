# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import missingno as ms
from pandas_profiling import ProfileReport
import numpy as np
import re
from sklearn import tree
import os
import datetime
# Out:
# /Users/keweichen/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import EC_utilities.EC_Scoring.EC_JupyterNoteBook_Setting as IDE

from EC_utilities.EC_Scoring.EC_Base import *
from EC_utilities.EC_Scoring.EC_DataStep import *
from EC_utilities.EC_Scoring.EC_FeaturesSelection import *
from EC_utilities.EC_Scoring.EC_MachineLearning import *

from EC_utilities.scikitplot import *



from Eric_utilites.Eric_DataDrop import *
from Eric_utilites.Eric_DataProcessing import *



pd.set_option('Display.max_columns',None)
pd.set_option('Display.max_rows',200)

Datafolder = 'Data'
Inputfolder = 'Inputfolder'
hdf_name = 'Data_final.h5'


hdf_output_path = f_PathFileName(Datafolder,hdf_name)


filename = 'df_final0907.csv'

# %%
Data = pd.read_hdf('Data/Data_final.h5',key = 'start_data')

# %%
Data.head()
# Out:
#                           CASEBASE_CPCN1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780           鐵研科技股份有限公司
# 0801110002 C0180073         長園科技實業股份有限公司
# 0801110003 C94C015B           僑威科技股份有限公司
# 0801110004 C95B0268         同泰電子科技股份有限公司
# 0801110005 C9840316           台郡科技股份有限公司
#
#                                                   CASEBASE_CPEN1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     TAK TECHNOLOGY CO., LTD.
# 0801110002 C0180073        CHANGS ASCENDING ENTERPRISE CO., LTD.
# 0801110003 C94C015B            CHANNEL WELL TECHNOLOGY CO., LTD.
# 0801110004 C95B0268                      UNIFLEX TECHNOLOGY INC.
# 0801110005 C9840316                   FLEXIUM INTERCONNECT, INC.
#
#                                CASEBASE_BILLAR CASEBASE_TAXNUM CASEBASE_CEMPL  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780        桃園市蘆竹區海湖村20鄰海湖51-7號        97272386            NaN
# 0801110002 C0180073            台中市北區進化北路231-7號        16207745              約
# 0801110003 C94C015B            桃園市蘆竹區南崁路二段222號        84573516            NaN
# 0801110004 C95B0268         台中縣大甲鎮幼獅工業區青年路123號        23983947            NaN
# 0801110005 C9840316         高雄縣大寮鄉大發工業區莒光一街23號        16347324            NaN
#
#                            CASEBASE_EMPLNUM  CASEBASE_BUILDATE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     101               24.0
# 0801110002 C0180073                      50               23.0
# 0801110003 C94C015B                     160               27.0
# 0801110004 C95B0268                     759               30.0
# 0801110005 C9840316                     632               23.0
#
#                           CASEBASE_CCOMPTYPE CASEBASE_CBUSKIND  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     大型企業               製造業
# 0801110002 C0180073                     中型企業               製造業
# 0801110003 C94C015B                     大型企業               製造業
# 0801110004 C95B0268                     大型企業               製造業
# 0801110005 C9840316                     大型企業               製造業
#
#                           CASEBASE_BUSTYPE CASEBASE_RANK  CASEBASE_LEGAL  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                 129999             B             1.0
# 0801110002 C0180073                 140401             B             1.0
# 0801110003 C94C015B                 129999             B             1.0
# 0801110004 C95B0268                 121201             B             1.0
# 0801110005 C9840316                 121201             B             1.0
#
#                              CASEBASE_OFFICEAR  CASEBASE_REGISTMONEY  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780        桃園市蘆竹區海湖村20鄰海湖51-7號              756997.0
# 0801110002 C0180073        台中市西屯區台中工業區工業三十四路5號              385000.0
# 0801110003 C94C015B            桃園市蘆竹區南崁路二段222號             1504000.0
# 0801110004 C95B0268         台北市內湖區瑞光路583巷30號2樓             1075290.0
# 0801110005 C9840316         高雄縣大寮鄉大發工業區莒光一街23號             1193121.0
#
#                           CASEBASE_REGISTDIRECT  CASEBASE_OPENINGTIME  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         楊惠民                   0.0
# 0801110002 C0180073                        張李琇玉                   0.0
# 0801110003 C94C015B                         潘君威                   0.0
# 0801110004 C95B0268                         李文彥                   0.0
# 0801110005 C9840316                         鄭明智                   0.0
#
#                           CASEBASE_CPJN1 CASEBASE_CCOUNTYOE CASEBASE_CCAPCURR  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780           鐵研科技股份有限公司                桃園縣               新台幣
# 0801110002 C0180073         長園科技實業股份有限公司                台中市               新台幣
# 0801110003 C94C015B                  NaN                桃園縣               新台幣
# 0801110004 C95B0268         同泰電子科技股份有限公司                台北市               新台幣
# 0801110005 C9840316           台郡科技股份有限公司                高雄縣               新台幣
#
#                           CASEBASE_LICENSE  CASEBASE_NACE_ID  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    NaN               NaN
# 0801110002 C0180073                    NaN               NaN
# 0801110003 C94C015B                    NaN               NaN
# 0801110004 C95B0268                    NaN               NaN
# 0801110005 C9840316                    NaN               NaN
#
#                           CASEBASE_NACE_CNAME  CASEBASE_SIC_ID  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       NaN              NaN
# 0801110002 C0180073                       NaN              NaN
# 0801110003 C94C015B                       NaN              NaN
# 0801110004 C95B0268                       NaN              NaN
# 0801110005 C9840316                       NaN              NaN
#
#                           CASEBASE_SIC_CNAME CASEBASE_DEFRANK  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      NaN              NaN
# 0801110002 C0180073                      NaN              NaN
# 0801110003 C94C015B                      NaN              NaN
# 0801110004 C95B0268                      NaN              NaN
# 0801110005 C9840316                      NaN              NaN
#
#                           CASEBASE_CCOMPSTATE  CASEBASE_NPL_IND  CASEBASE_NPL  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       NaN               NaN           NaN
# 0801110002 C0180073                       NaN               NaN           NaN
# 0801110003 C94C015B                       NaN               NaN           NaN
# 0801110004 C95B0268                       NaN               NaN           NaN
# 0801110005 C9840316                       NaN               NaN           NaN
#
#                            CASEBASE1_FACTORY  CASEBASE1_CONGLOME  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      2.0                 5.0
# 0801110002 C0180073                      2.0                 0.0
# 0801110003 C94C015B                      1.0                13.0
# 0801110004 C95B0268                      3.0                 6.0
# 0801110005 C9840316                      2.0                 8.0
#
#                            CASEBASE1_HISTYPE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      1.0
# 0801110002 C0180073                      1.0
# 0801110003 C94C015B                      1.0
# 0801110004 C95B0268                      1.0
# 0801110005 C9840316                      0.0
#
#                                                 CASEBASE1_BFNAME  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                鐵研股份有限公司TAK FERRITE CO., LTD.
# 0801110002 C0180073                                   長園實業股份有限公司
# 0801110003 C94C015B                                     僑威科技有限公司
# 0801110004 C95B0268        僑大工業股份有限公司Chiao Ta Industry Co., Ltd.
# 0801110005 C9840316                                          NaN
#
#                            CASEBASE1_HISTORY  CASEBASE1_SALEITEM  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      1.0                 2.0
# 0801110002 C0180073                      1.0                 1.0
# 0801110003 C94C015B                      1.0                 2.0
# 0801110004 C95B0268                      1.0                 1.0
# 0801110005 C9840316                      0.0                 1.0
#
#                            CASEBASE1_CAPTIAL  CASEBASE1_COOPEIN  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      9.0                0.0
# 0801110002 C0180073                      9.0                0.0
# 0801110003 C94C015B                     10.0                0.0
# 0801110004 C95B0268                      8.0                0.0
# 0801110005 C9840316                     12.0                0.0
#
#                            CASEBASE1_COOPEOUT  CASEBASE1_STOCKER  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       0.0                0.0
# 0801110002 C0180073                       0.0                0.0
# 0801110003 C94C015B                       0.0                0.0
# 0801110004 C95B0268                       0.0                0.0
# 0801110005 C9840316                       0.0                0.0
#
#                            CASEBASE1_STOCKH   CASEBASE1_OPERATER  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    10.0                  楊惠民
# 0801110002 C0180073                    10.0                 張李琇玉
# 0801110003 C94C015B                     9.0                  潘君威
# 0801110004 C95B0268                    13.0                  徐又中
# 0801110005 C9840316                    10.0  鄭明智主導台鵬開發股份有限公司投資設立
#
#                           CASEBASE1_OPEOFFER  CASEBASE1_OPERATE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  公開資料/側查                1.0
# 0801110002 C0180073                財務經理蔡秀芬小姐                2.0
# 0801110003 C94C015B          財務部 王郁潔課長核對#272                2.0
# 0801110004 C95B0268                       側查                1.0
# 0801110005 C9840316                 行政處處長胡斌成                1.0
#
#                            CASEBASE1_MPLANT CASEBASE1_MPLOFFER  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     1.0               公開資料
# 0801110002 C0180073                     1.0          財務經理蔡秀芬小姐
# 0801110003 C94C015B                     1.0          財務部 王郁潔課長
# 0801110004 C95B0268                     2.0              陳文川協理
# 0801110005 C9840316                     1.0           行政處處長胡斌成
#
#                            CASEBASE1_PROCPLANT  CASEBASE1_PAWN  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        0.0             1.0
# 0801110002 C0180073                        3.0             0.0
# 0801110003 C94C015B                        1.0             0.0
# 0801110004 C95B0268                        6.0             1.0
# 0801110005 C9840316                       10.0             1.0
#
#                            CASEBASE1_PAWNNUM  CASEBASE1_RATEY1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      2.0             100.0
# 0801110002 C0180073                      NaN             100.0
# 0801110003 C94C015B                      NaN             100.0
# 0801110004 C95B0268                      7.0             100.0
# 0801110005 C9840316                      2.0             100.0
#
#                            CASEBASE1_RATEY2  CASEBASE1_RATEY3  CASEBASE1_GPY1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   100.0             100.0           14.86
# 0801110002 C0180073                   100.0             100.0          -32.18
# 0801110003 C94C015B                   100.0             100.0           -1.08
# 0801110004 C95B0268                   100.0             100.0           45.38
# 0801110005 C9840316                   100.0             100.0           -8.59
#
#                            CASEBASE1_GPY2  CASEBASE1_OPENYEAR  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                 11.30                 2.0
# 0801110002 C0180073                -78.71                 2.0
# 0801110003 C94C015B                  5.34                 3.0
# 0801110004 C95B0268                  7.08                 2.0
# 0801110005 C9840316                -18.90                 2.0
#
#                           CASEBASE1_SALEAMT  CASEBASE1_SALESTAT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                 838,279                 3.0
# 0801110002 C0180073                  50,939                 3.0
# 0801110003 C94C015B                       -                 1.0
# 0801110004 C95B0268               1,696,684                 4.0
# 0801110005 C9840316               1,571,641                 3.0
#
#                            CASEBASE1_STUFFIN  CASEBASE1_STLC  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      7.0             0.0
# 0801110002 C0180073                      1.0           100.0
# 0801110003 C94C015B                     11.0            10.0
# 0801110004 C95B0268                      6.0             0.0
# 0801110005 C9840316                      8.0            50.0
#
#                           CASEBASE1_STDADAY  CASEBASE1_STDA  CASEBASE1_STDP  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     NaN             0.0             0.0
# 0801110002 C0180073                     NaN             0.0             0.0
# 0801110003 C94C015B                     NaN             0.0             0.0
# 0801110004 C95B0268                     NaN             0.0             0.0
# 0801110005 C9840316                     NaN             0.0             0.0
#
#                           CASEBASE1_STUSDAY  CASEBASE1_STUS  CASEBASE1_STTT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     NaN             0.0             0.0
# 0801110002 C0180073                     NaN             0.0             0.0
# 0801110003 C94C015B                     NaN             0.0            90.0
# 0801110004 C95B0268                     NaN             0.0           100.0
# 0801110005 C9840316                     NaN             0.0            50.0
#
#                           CASEBASE1_STOADAY  CASEBASE1_STOA CASEBASE1_COTHER  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     NaN             0.0              依約定
# 0801110002 C0180073                     NaN             0.0              NaN
# 0801110003 C94C015B                     NaN             0.0              NaN
# 0801110004 C95B0268                     NaN             0.0              NaN
# 0801110005 C9840316                     NaN             0.0              NaN
#
#                            CASEBASE1_STOTHER  CASEBASE1_STOTHERTMP  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    100.0                   NaN
# 0801110002 C0180073                      0.0                   NaN
# 0801110003 C94C015B                      0.0                   NaN
# 0801110004 C95B0268                      0.0                   NaN
# 0801110005 C9840316                      0.0                   NaN
#
#                            CASEBASE1_STUFFOUT CASEBASE1_CCOUNTY  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       1.0               NaN
# 0801110002 C0180073                       2.0               NaN
# 0801110003 C94C015B                       2.0               NaN
# 0801110004 C95B0268                       2.0               NaN
# 0801110005 C9840316                       1.0               NaN
#
#                           CASEBASE1_ADDRNO  CASEBASE1_ADDRNONO  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    NaN                 NaN
# 0801110002 C0180073                    NaN                 NaN
# 0801110003 C94C015B                    NaN                 NaN
# 0801110004 C95B0268                    NaN                 NaN
# 0801110005 C9840316                    NaN                 NaN
#
#                           CASEBASE1_REGADDR  CASEBASE1_HISTORYLIST  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     NaN                    0.0
# 0801110002 C0180073                     NaN                    0.0
# 0801110003 C94C015B                     NaN                    0.0
# 0801110004 C95B0268                     NaN                    0.0
# 0801110005 C9840316                     NaN                    0.0
#
#                            CASEBASE1_SALEITEMM1  CASEBASE1_SALEITEMM2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         0.0                   0.0
# 0801110002 C0180073                         0.0                   0.0
# 0801110003 C94C015B                         0.0                   0.0
# 0801110004 C95B0268                         0.0                   0.0
# 0801110005 C9840316                         0.0                   0.0
#
#                           CASEBASE1_CCAPTDOLL CASEBASE1_OPEPRIZEOFFER  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       新台幣                     NaN
# 0801110002 C0180073                       新台幣                     NaN
# 0801110003 C94C015B                       新台幣                     NaN
# 0801110004 C95B0268                       新台幣                     NaN
# 0801110005 C9840316                       新台幣                     NaN
#
#                            CASEBASE1_BOARD CASEBASE1_CSALEDOLL  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    0.0                 新台幣
# 0801110002 C0180073                    0.0                 新台幣
# 0801110003 C94C015B                    0.0                 新台幣
# 0801110004 C95B0268                    0.0                 新台幣
# 0801110005 C9840316                    0.0                 新台幣
#
#                           CASEBASE1_STOTHERDAY CASEBASE1_CORGTYPE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          0               股票上櫃
# 0801110002 C0180073                          0               興櫃股票
# 0801110003 C94C015B                          0               股票上櫃
# 0801110004 C95B0268                          0               興櫃股票
# 0801110005 C9840316                        NaN               股票上市
#
#                           CASEBASE1_CSTOCKSTATE CASEBASE1_STOCKNO  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          正常              3369
# 0801110002 C0180073                          正常              8038
# 0801110003 C94C015B                          正常              3078
# 0801110004 C95B0268                          正常              3321
# 0801110005 C9840316                          正常              6269
#
#                            CASEBASE1_ONEEXPLAIN CASEBASE1_PAYDAY  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         1.0              NaN
# 0801110002 C0180073                         0.0              NaN
# 0801110003 C94C015B                         1.0              NaN
# 0801110004 C95B0268                         0.0              NaN
# 0801110005 C9840316                         0.0              NaN
#
#                           CASEBASE1_CHISTORYCHANGE1  CASEBASE1_OPEOFFER_SEX  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                             NaN                     0.0
# 0801110002 C0180073                             NaN                     0.0
# 0801110003 C94C015B                             NaN                     0.0
# 0801110004 C95B0268                             NaN                     0.0
# 0801110005 C9840316                             NaN                     0.0
#
#                           CASEBASE1_OPEOFFER1  CASEBASE1_OPEOFFER1_SEX  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       NaN                      0.0
# 0801110002 C0180073                       NaN                      0.0
# 0801110003 C94C015B                       NaN                      0.0
# 0801110004 C95B0268                       NaN                      0.0
# 0801110005 C9840316                       NaN                      0.0
#
#                            CASEBASE1_ISMERGER1  CASEBASE1_ISMERGER2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        0.0                  0.0
# 0801110002 C0180073                        0.0                  0.0
# 0801110003 C94C015B                        0.0                  0.0
# 0801110004 C95B0268                        0.0                  0.0
# 0801110005 C9840316                        0.0                  0.0
#
#                            CASEBASE1_ISMERGER3 CASEBASE1_NETINAMT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        0.0                NaN
# 0801110002 C0180073                        0.0                NaN
# 0801110003 C94C015B                        0.0                NaN
# 0801110004 C95B0268                        0.0                NaN
# 0801110005 C9840316                        0.0                NaN
#
#                            CASEBASE1_STOCKPRICE_YM  CASEBASE2_STUFFIN2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                            NaN                 0.0
# 0801110002 C0180073                            NaN                 2.0
# 0801110003 C94C015B                            NaN                 6.0
# 0801110004 C95B0268                            NaN                 5.0
# 0801110005 C9840316                            NaN                10.0
#
#                            CASEBASE2_PSLC CASEBASE2_PSDADAY  CASEBASE2_PSDA  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   0.0               NaN             0.0
# 0801110002 C0180073                 100.0               NaN             0.0
# 0801110003 C94C015B                   0.0               NaN             0.0
# 0801110004 C95B0268                   0.0               NaN             0.0
# 0801110005 C9840316                  50.0               NaN             0.0
#
#                            CASEBASE2_PSDP CASEBASE2_PSUSDAY  CASEBASE2_PSUS  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   0.0               NaN             0.0
# 0801110002 C0180073                   0.0               NaN             0.0
# 0801110003 C94C015B                   0.0               NaN             0.0
# 0801110004 C95B0268                   0.0               NaN             0.0
# 0801110005 C9840316                   0.0               NaN             0.0
#
#                            CASEBASE2_PSTT CASEBASE2_PSOADAY  CASEBASE2_PSOA  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   0.0               NaN             0.0
# 0801110002 C0180073                   0.0               NaN             0.0
# 0801110003 C94C015B                 100.0               NaN             0.0
# 0801110004 C95B0268                 100.0               NaN             0.0
# 0801110005 C9840316                  50.0               NaN             0.0
#
#                           CASEBASE2_COTHER  CASEBASE2_PSOTHER  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    依約定              100.0
# 0801110002 C0180073                    NaN                0.0
# 0801110003 C94C015B                    NaN                0.0
# 0801110004 C95B0268                    NaN                0.0
# 0801110005 C9840316                    NaN                0.0
#
#                            CASEBASE2_PSOTHERTMP  CASEBASE2_STUFFOUT2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         NaN                  1.0
# 0801110002 C0180073                         NaN                  2.0
# 0801110003 C94C015B                         NaN                  1.0
# 0801110004 C95B0268                         NaN                  4.0
# 0801110005 C9840316                         NaN                  1.0
#
#                            CASEBASE2_BANK CASEBASE2_BILL1 CASEBASE2_BILL2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   0.0               N               Y
# 0801110002 C0180073                   2.0               N               N
# 0801110003 C94C015B                   1.0               N               N
# 0801110004 C95B0268                   2.0               N               N
# 0801110005 C9840316                   2.0               N               N
#
#                           CASEBASE2_BILL3   CASEBASE2_BILLDATE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     Y  2008-01-11 00:00:00
# 0801110002 C0180073                     N  2008-01-11 00:00:00
# 0801110003 C94C015B                     N  2008-01-11 00:00:00
# 0801110004 C95B0268                     Y  2008-01-04 00:00:00
# 0801110005 C9840316                     Y  2008-01-04 00:00:00
#
#                            CASEBASE2_COMPBILL  CASEBASE2_PRESBILL  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       0.0                 1.0
# 0801110002 C0180073                       0.0                 0.0
# 0801110003 C94C015B                       0.0                 0.0
# 0801110004 C95B0268                       0.0                 0.0
# 0801110005 C9840316                       0.0                 0.0
#
#                           CASEBASE2_REFUND0 CASEBASE2_REFUND1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       Y                 N
# 0801110002 C0180073                     NaN               NaN
# 0801110003 C94C015B                       Y                 Y
# 0801110004 C95B0268                       Y                 N
# 0801110005 C9840316                       Y                 N
#
#                           CASEBASE2_REFUND2 CASEBASE2_REFUND3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       N                 N
# 0801110002 C0180073                     NaN               NaN
# 0801110003 C94C015B                       Y                 Y
# 0801110004 C95B0268                       Y                 Y
# 0801110005 C9840316                       Y                 Y
#
#                           CASEBASE2_REFUND4  CASEBASE2_REFUND  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       Y               0.0
# 0801110002 C0180073                       Y               0.0
# 0801110003 C94C015B                       Y               0.0
# 0801110004 C95B0268                       Y               0.0
# 0801110005 C9840316                       Y               0.0
#
#                            CASEBASE2_REJECTREC  CASEBASE2_REJECT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        0.0               0.0
# 0801110002 C0180073                        0.0               0.0
# 0801110003 C94C015B                        0.0               0.0
# 0801110004 C95B0268                        0.0               0.0
# 0801110005 C9840316                        0.0               0.0
#
#                            CASEBASE2_REJECTNO  CASEBASE2_LAWSUITREC  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       NaN                   0.0
# 0801110002 C0180073                       NaN                   1.0
# 0801110003 C94C015B                       NaN                   1.0
# 0801110004 C95B0268                       NaN                   1.0
# 0801110005 C9840316                       NaN                   1.0
#
#                            CASEBASE2_LAWSUIT  CASEBASE2_PATENT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      0.0               0.0
# 0801110002 C0180073                      1.0               1.0
# 0801110003 C94C015B                      1.0               1.0
# 0801110004 C95B0268                      2.0               0.0
# 0801110005 C9840316                      2.0               1.0
#
#                            CASEBASE2_PANTENTNO CASEBASE2_PLACE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        0.0             NaN
# 0801110002 C0180073                        4.0             NaN
# 0801110003 C94C015B                       13.0             NaN
# 0801110004 C95B0268                        0.0             NaN
# 0801110005 C9840316                        7.0             NaN
#
#                           CASEBASE2_PLACENAME  CASEBASE2_PLACELIST  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       NaN                  0.0
# 0801110002 C0180073                       NaN                  0.0
# 0801110003 C94C015B                       NaN                  0.0
# 0801110004 C95B0268                       NaN                  0.0
# 0801110005 C9840316                       NaN                  0.0
#
#                            CASEBASE2_PLACENUM CASEBASE2_BUSNAME  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       0.0           被動電子元件業
# 0801110002 C0180073                       0.0               電池業
# 0801110003 C94C015B                       0.0          其他電子零組件業
# 0801110004 C95B0268                       0.0            印刷電路板業
# 0801110005 C9840316                       0.0            印刷電路板業
#
#                           CASEBASE2_BUSNAME2  CASEBASE2_EPLIST  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      NaN               5.0
# 0801110002 C0180073                      NaN               5.0
# 0801110003 C94C015B                      NaN               5.0
# 0801110004 C95B0268                      NaN               5.0
# 0801110005 C9840316                      NaN               5.0
#
#                            CASEBASE2_INOUT   CASEBASE2_FINDATE2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    2.0  2005-12-31 00:00:00
# 0801110002 C0180073                    2.0  2005-12-31 00:00:00
# 0801110003 C94C015B                    2.0  2005-12-31 00:00:00
# 0801110004 C95B0268                    3.0  2005-12-31 00:00:00
# 0801110005 C9840316                    3.0  2005-12-31 00:00:00
#
#                             CASEBASE2_FINDATE3  CASEBASE2_FINANCIAL  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780        2004-12-31 00:00:00                  8.0
# 0801110002 C0180073        2004-12-31 00:00:00                  8.0
# 0801110003 C94C015B        2004-12-31 00:00:00                  8.0
# 0801110004 C95B0268        2004-12-31 00:00:00                  8.0
# 0801110005 C9840316        2004-12-31 00:00:00                  8.0
#
#                            CASEBASE2_FINSTATE CASEBASE2_TAXTYPE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       0.0                 N
# 0801110002 C0180073                       0.0                 N
# 0801110003 C94C015B                       0.0                 N
# 0801110004 C95B0268                       0.0                 N
# 0801110005 C9840316                       0.0                 N
#
#                            CASEBASE2_TAXY1  CASEBASE2_TAXY2  CASEBASE2_TAXY3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    NaN              NaN              NaN
# 0801110002 C0180073                    NaN              NaN              NaN
# 0801110003 C94C015B                    NaN              NaN              NaN
# 0801110004 C95B0268                    NaN              NaN              NaN
# 0801110005 C9840316                    NaN              NaN              NaN
#
#                           CASEBASE2_CPATYPE  CASEBASE2_CPAY1  CASEBASE2_CPAY2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       Y           2006.0           2005.0
# 0801110002 C0180073                       Y           2006.0           2005.0
# 0801110003 C94C015B                       Y           2006.0           2005.0
# 0801110004 C95B0268                       Y           2006.0           2005.0
# 0801110005 C9840316                       Y           2006.0           2005.0
#
#                            CASEBASE2_CPAY3 CASEBASE2_COMPTYPE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                 2004.0                  N
# 0801110002 C0180073                 2004.0                  N
# 0801110003 C94C015B                 2004.0                  N
# 0801110004 C95B0268                 2004.0                  N
# 0801110005 C9840316                 2004.0                  N
#
#                            CASEBASE2_COMPY1  CASEBASE2_COMPY2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     NaN               NaN
# 0801110002 C0180073                     NaN               NaN
# 0801110003 C94C015B                     NaN               NaN
# 0801110004 C95B0268                     NaN               NaN
# 0801110005 C9840316                     NaN               NaN
#
#                            CASEBASE2_COMPY3  CASEBASE2_HISNEWS  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     NaN                0.0
# 0801110002 C0180073                     NaN                0.0
# 0801110003 C94C015B                     NaN                0.0
# 0801110004 C95B0268                     NaN                0.0
# 0801110005 C9840316                     NaN                0.0
#
#                            CASEBASE2_NEWS  CASEBASE2_PRIZE  CASEBASE2_BASIS  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   0.0              0.0              9.0
# 0801110002 C0180073                   0.0              0.0              9.0
# 0801110003 C94C015B                   4.0              0.0              9.0
# 0801110004 C95B0268                   2.0              0.0              9.0
# 0801110005 C9840316                   5.0              0.0              0.0
#
#                           CASEBASE2_PROPOSAL CASEBASE2_CDOLLTYPE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        Z                 NaN
# 0801110002 C0180073                        Z                 NaN
# 0801110003 C94C015B                        Z                 NaN
# 0801110004 C95B0268                        Z                 NaN
# 0801110005 C9840316                        Z                 NaN
#
#                            CASEBASE2_RPTTYPE  CASEBASE2_CTRANDATE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      2.0  2009-04-09 09:39:57
# 0801110002 C0180073                      2.0  2008-01-17 10:05:02
# 0801110003 C94C015B                      2.0  2008-01-16 16:30:03
# 0801110004 C95B0268                      2.0  2008-01-08 16:21:05
# 0801110005 C9840316                      2.0  2008-01-09 11:27:24
#
#                           CASEBASE2_PSOTHERDAY  CASEBASE2_PUBLIC1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          0                NaN
# 0801110002 C0180073                          0                NaN
# 0801110003 C94C015B                          0                NaN
# 0801110004 C95B0268                          0                NaN
# 0801110005 C9840316                          0                NaN
#
#                            CASEBASE2_MPUBLIC1  CASEBASE2_MPUBLIC  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       NaN                0.0
# 0801110002 C0180073                       NaN                0.0
# 0801110003 C94C015B                       NaN                0.0
# 0801110004 C95B0268                       NaN                0.0
# 0801110005 C9840316                       NaN                0.0
#
#                           CASEBASE2_CCREDITPAY CASEBASE2_CREDITPAYDAY  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        NaN                    NaN
# 0801110002 C0180073                        NaN                    NaN
# 0801110003 C94C015B                        NaN                    NaN
# 0801110004 C95B0268                        NaN                    NaN
# 0801110005 C9840316                        NaN                    NaN
#
#                            CASEBASE2_PAYHISTORY  CASEBASE2_PAYHISTORY2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         0.0                    0.0
# 0801110002 C0180073                         0.0                    0.0
# 0801110003 C94C015B                         0.0                    0.0
# 0801110004 C95B0268                         0.0                    0.0
# 0801110005 C9840316                         0.0                    0.0
#
#                           CASEBASE2_NOFINRPT CASEBASE2_FINSTATENAME  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        N                    NaN
# 0801110002 C0180073                        N                    NaN
# 0801110003 C94C015B                        N                    NaN
# 0801110004 C95B0268                        N                    NaN
# 0801110005 C9840316                        N                    NaN
#
#                           CASEBASE2_MAXCREDIT CASEBASE2_CMAXCURRENCY  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         N                    NaN
# 0801110002 C0180073                         N                    NaN
# 0801110003 C94C015B                         N                    NaN
# 0801110004 C95B0268                         Y                    新台幣
# 0801110005 C9840316                         Y                    新台幣
#
#                           CASEBASE2_MAXMONEY CASEBASE2_PROCREDIT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      NaN                   N
# 0801110002 C0180073                      NaN                   N
# 0801110003 C94C015B                      NaN                   N
# 0801110004 C95B0268              120,000,000                   N
# 0801110005 C9840316              100,000,000                   N
#
#                            CASEBASE2_ASSET  CASEBASE2_AFTERTAX  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    0.0                 0.0
# 0801110002 C0180073                    NaN                 NaN
# 0801110003 C94C015B                    NaN                 NaN
# 0801110004 C95B0268                    0.0                 0.0
# 0801110005 C9840316                    0.0                 0.0
#
#                           CASEBASE2_FUNDDAY CASEBASE2_SALEDAY  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     NaN               NaN
# 0801110002 C0180073                     NaN               NaN
# 0801110003 C94C015B                     NaN               NaN
# 0801110004 C95B0268                     NaN               NaN
# 0801110005 C9840316                     NaN               NaN
#
#                           CASEBASE2_CDOLLTYPE1 CASEBASE2_CFINSTATE1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        NaN                  NaN
# 0801110002 C0180073                        NaN                  NaN
# 0801110003 C94C015B                        NaN                  NaN
# 0801110004 C95B0268                        NaN                  NaN
# 0801110005 C9840316                        NaN                  NaN
#
#                           CASEBASE2_CFINSTATE2 CASEBASE2_CFINSTATE3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        NaN                  NaN
# 0801110002 C0180073                        NaN                  NaN
# 0801110003 C94C015B                        NaN                  NaN
# 0801110004 C95B0268                        NaN                  NaN
# 0801110005 C9840316                        NaN                  NaN
#
#                            CASEBASE2_AQUICK1  CASEBASE2_LQUICK1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      NaN                NaN
# 0801110002 C0180073                      NaN                NaN
# 0801110003 C94C015B                      NaN                NaN
# 0801110004 C95B0268                      NaN                NaN
# 0801110005 C9840316                      NaN                NaN
#
#                            CASEBASE2_LKEEP1  CASEBASE2_AQUICK2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     NaN                NaN
# 0801110002 C0180073                     NaN                NaN
# 0801110003 C94C015B                     NaN                NaN
# 0801110004 C95B0268                     NaN                NaN
# 0801110005 C9840316                     NaN                NaN
#
#                            CASEBASE2_LQUICK2  CASEBASE2_LKEEP2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      NaN               NaN
# 0801110002 C0180073                      NaN               NaN
# 0801110003 C94C015B                      NaN               NaN
# 0801110004 C95B0268                      NaN               NaN
# 0801110005 C9840316                      NaN               NaN
#
#                            CASEBASE2_AQUICK3  CASEBASE2_LQUICK3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      NaN                NaN
# 0801110002 C0180073                      NaN                NaN
# 0801110003 C94C015B                      NaN                NaN
# 0801110004 C95B0268                      NaN                NaN
# 0801110005 C9840316                      NaN                NaN
#
#                            CASEBASE2_LKEEP3  CASEBASE2_NGETMSTOCK  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     NaN                   0.0
# 0801110002 C0180073                     NaN                   0.0
# 0801110003 C94C015B                     NaN                   0.0
# 0801110004 C95B0268                     NaN                   0.0
# 0801110005 C9840316                     NaN                   0.0
#
#                           CASEBASE2_STOCK1 CASEBASE2_STOCK2 CASEBASE2_STOCK3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    NaN              NaN              NaN
# 0801110002 C0180073                    NaN              NaN              NaN
# 0801110003 C94C015B                    NaN              NaN              NaN
# 0801110004 C95B0268                    NaN              NaN              NaN
# 0801110005 C9840316                    NaN              NaN              NaN
#
#                            CASEBASE2_SHOWTYPE CASEBASE2_FINDATEM1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       0.0                 NaN
# 0801110002 C0180073                       0.0                 NaN
# 0801110003 C94C015B                       0.0                 NaN
# 0801110004 C95B0268                       0.0                 NaN
# 0801110005 C9840316                       0.0                 NaN
#
#                           CASEBASE2_FINDATEM2 CASEBASE2_FINDATEM3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       NaN                 NaN
# 0801110002 C0180073                       NaN                 NaN
# 0801110003 C94C015B                       NaN                 NaN
# 0801110004 C95B0268                       NaN                 NaN
# 0801110005 C9840316                       NaN                 NaN
#
#                            CASEBASE2_FINANCIALM  CASEBASE2_AQUICKM1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         NaN                 NaN
# 0801110002 C0180073                         NaN                 NaN
# 0801110003 C94C015B                         NaN                 NaN
# 0801110004 C95B0268                         NaN                 NaN
# 0801110005 C9840316                         NaN                 NaN
#
#                            CASEBASE2_LQUICKM1  CASEBASE2_LKEEPM1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       NaN                NaN
# 0801110002 C0180073                       NaN                NaN
# 0801110003 C94C015B                       NaN                NaN
# 0801110004 C95B0268                       NaN                NaN
# 0801110005 C9840316                       NaN                NaN
#
#                            CASEBASE2_AQUICKM2  CASEBASE2_LQUICKM2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       NaN                 NaN
# 0801110002 C0180073                       NaN                 NaN
# 0801110003 C94C015B                       NaN                 NaN
# 0801110004 C95B0268                       NaN                 NaN
# 0801110005 C9840316                       NaN                 NaN
#
#                            CASEBASE2_LKEEPM2  CASEBASE2_AQUICKM3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      NaN                 NaN
# 0801110002 C0180073                      NaN                 NaN
# 0801110003 C94C015B                      NaN                 NaN
# 0801110004 C95B0268                      NaN                 NaN
# 0801110005 C9840316                      NaN                 NaN
#
#                            CASEBASE2_LQUICKM3  CASEBASE2_LKEEPM3  \
# ...
# 0801110002 C0180073                      2709.0                 17.0
# 0801110003 C94C015B                      2709.0                116.0
# 0801110004 C95B0268                      2709.0                 75.0
# 0801110005 C9840316                      2709.0                 75.0
#
#                            CASEBASE5_COMPBUSNO  CASEBASE5_TOPAVGEMP  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       37.0                288.0
# 0801110002 C0180073                        0.0                295.0
# 0801110003 C94C015B                       19.0                470.0
# 0801110004 C95B0268                       25.0                793.0
# 0801110005 C9840316                       32.0                793.0
#
#                            CASEBASE5_TOPAVGSALE  CASEBASE5_TOPMAXSORT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   2041684.0                 312.0
# 0801110002 C0180073                   3510459.0                 236.0
# 0801110003 C94C015B                   5529818.0                  24.0
# 0801110004 C95B0268                   4943723.0                  79.0
# 0801110005 C9840316                   4943723.0                  79.0
#
#                            CASEBASE5_TOPMINSORT  CASEBASE5_TOPNOWSORT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      4921.0                2579.0
# 0801110002 C0180073                      4326.0                   0.0
# 0801110003 C94C015B                      4783.0                 859.0
# 0801110004 C95B0268                      4855.0                1122.0
# 0801110005 C9840316                      4855.0                1458.0
#
#                            CASEBASE5_TOPMAXBUSSORT  CASEBASE5_TOPMINBUSSORT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          156.0                   2703.0
# 0801110002 C0180073                          116.0                   2464.0
# 0801110003 C94C015B                           12.0                   2652.0
# 0801110004 C95B0268                           41.0                   2680.0
# 0801110005 C9840316                           41.0                   2680.0
#
#                            CASEBASE5_TOPNOWBUSSORT  CASEBASE5_TOPMAXEMP  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         1513.0               2586.0
# 0801110002 C0180073                            0.0                905.0
# 0801110003 C94C015B                          468.0              13322.0
# 0801110004 C95B0268                          623.0               5985.0
# 0801110005 C9840316                          826.0               5985.0
#
#                            CASEBASE5_TOPMINEMP  CASEBASE5_TOPNOWEMP  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       15.0                101.0
# 0801110002 C0180073                       50.0                 50.0
# 0801110003 C94C015B                       10.0                160.0
# 0801110004 C95B0268                       40.0                759.0
# 0801110005 C9840316                       40.0                632.0
#
#                            CASEBASE5_TOPMAXSALE  CASEBASE5_TOPMINSALE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  13165645.0              125298.0
# 0801110002 C0180073                  16310066.0              220540.0
# 0801110003 C94C015B                 181652407.0              129934.0
# 0801110004 C95B0268                  49801871.0              115900.0
# 0801110005 C9840316                  49801871.0              115900.0
#
#                            CASEBASE5_TOPNOWSALE  CASEBASE5_NOWSALEY  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    805638.0              2006.0
# 0801110002 C0180073                     31993.0              2006.0
# 0801110003 C94C015B                   3839219.0              2006.0
# 0801110004 C95B0268                   2736536.0              2006.0
# 0801110005 C9840316                   1908341.0              2006.0
#
#                            CASEBASE5_TOPMAXCAP  CASEBASE5_TOPMINCAP  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                 24382213.0              50000.0
# 0801110002 C0180073                  2036188.0              54000.0
# 0801110003 C94C015B                 76235909.0              20000.0
# 0801110004 C95B0268                 12071291.0              40660.0
# 0801110005 C9840316                 12071291.0              40660.0
#
#                            CASEBASE5_TOPNOWCAP  CASEBASE5_FINACETYPE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   756997.0                   1.0
# 0801110002 C0180073                   385000.0                   1.0
# 0801110003 C94C015B                  1504000.0                   1.0
# 0801110004 C95B0268                  1075290.0                   1.0
# 0801110005 C9840316                  1193121.0                   1.0
#
#                            CASEBASE5_FINACEYEAR  CASEBASE5_FINANCEBUSID  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      2007.0                129900.0
# 0801110002 C0180073                      2006.0                140400.0
# 0801110003 C94C015B                      2006.0                129900.0
# 0801110004 C95B0268                      2006.0                121200.0
# 0801110005 C9840316                      2006.0                121200.0
#
#                           CASEBASE5_FINANCEBUSNAME  CASEBASE5_MED02  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       其他電子零組件業            12.39
# 0801110002 C0180073                            電池業            17.99
# 0801110003 C94C015B                       其他電子零組件業            14.64
# 0801110004 C95B0268                         印刷電路板業            25.62
# 0801110005 C9840316                         印刷電路板業            25.62
#
#                            CASEBASE5_MED06  CASEBASE5_MED09  CASEBASE5_MED10  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  35.57           535.19            55.14
# 0801110002 C0180073                  41.06           400.88             0.00
# 0801110003 C94C015B                  39.11           475.16             0.00
# 0801110004 C95B0268                  42.15           258.91             0.00
# 0801110005 C9840316                  42.15           258.91             0.00
#
#                            CASEBASE5_MED11  CASEBASE5_MED23  CASEBASE5_MED24  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    0.0             6.48            10.61
# 0801110002 C0180073                    0.0             5.34            11.99
# 0801110003 C94C015B                    0.0             6.00             9.80
# 0801110004 C95B0268                    0.0             7.21            11.46
# 0801110005 C9840316                    0.0             7.21            11.46
#
#                            CASEBASE5_MED25  CASEBASE5_MED26  CASEBASE5_MED27  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   6.72            18.54              0.0
# 0801110002 C0180073                   6.03            37.86              0.0
# 0801110003 C94C015B                   6.30            18.54              0.0
# 0801110004 C95B0268                   7.51            20.97              0.0
# 0801110005 C9840316                   7.51            20.97              0.0
#
#                            CASEBASE5_MED41  CASEBASE5_MED42  CASEBASE5_MED43  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   9.32             3.42             6.21
# 0801110002 C0180073                   6.10             4.55             5.87
# 0801110003 C94C015B                   7.80             3.52             5.34
# 0801110004 C95B0268                   9.05             3.11             2.96
# 0801110005 C9840316                   9.05             3.11             2.96
#
#                            CASEBASE5_MED45  CASEBASE5_MED49  CASEBASE5_MED50  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   0.86              0.0             5.36
# 0801110002 C0180073                   0.83              0.0             6.36
# 0801110003 C94C015B                   0.81              0.0             5.09
# 0801110004 C95B0268                   0.80              0.0             4.90
# 0801110005 C9840316                   0.80              0.0             4.90
#
#                            CASEBASE5_MED51  CASEBASE5_MED61  CASEBASE5_MED62  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   68.0           186.26           146.38
# 0801110002 C0180073                   58.0           179.61           123.03
# 0801110003 C94C015B                   72.0           165.80           137.10
# 0801110004 C95B0268                   75.0           145.34           116.54
# 0801110005 C9840316                   75.0           145.34           116.54
#
#                            CASEBASE5_MED64  CASEBASE5_MED65  CASEBASE5_MED67  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  37.22           108.44            14.02
# 0801110002 C0180073                  60.55            81.42            15.60
# 0801110003 C94C015B                  45.57           105.28            14.04
# 0801110004 C95B0268                  40.01           119.25            15.97
# 0801110005 C9840316                  40.01           119.25            15.97
#
#                            CASEBASE5_MED71  CASEBASE5_MED72  CASEBASE5_MED22  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  12.77             4.94              0.0
# 0801110002 C0180073                   5.49             0.13              0.0
# 0801110003 C94C015B                  19.67             7.22              0.0
# 0801110004 C95B0268                  21.92             6.55              0.0
# 0801110005 C9840316                  21.92             6.55              0.0
#
#                            CASEBASE5_MED21  CASEBASE5_MED44  CASEBASE5_REC_NO  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    0.0              0.0             160.0
# 0801110002 C0180073                    0.0              0.0              10.0
# 0801110003 C94C015B                    0.0              0.0             146.0
# 0801110004 C95B0268                    0.0              0.0              60.0
# 0801110005 C9840316                    0.0              0.0              60.0
#
#                           CASEBASE5_CEMPLID  CASEBASE5_MEMPLID  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   01059              546.0
# 0801110002 C0180073                   01057              982.0
# 0801110003 C94C015B                   01057              546.0
# 0801110004 C95B0268                   01119              982.0
# 0801110005 C9840316                   01124              982.0
#
#                            CASEBASE5_TOPAVGCAP  CASEBASE5_TOPNOWASST  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  1236431.0             1811326.0
# 0801110002 C0180073                   801170.0              196029.0
# 0801110003 C94C015B                  1955412.0             3143217.0
# 0801110004 C95B0268                  1608159.0             2879075.0
# 0801110005 C9840316                  1608159.0             2526886.0
#
#                            CASEBASE5_TOPNOWNETWRT  CASEBASE5_TOPMAXASST  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      852689.0            49603313.0
# 0801110002 C0180073                      125566.0             9136650.0
# 0801110003 C94C015B                     2021511.0           374446256.0
# 0801110004 C95B0268                     1199624.0            47779916.0
# 0801110005 C9840316                     1291005.0            47779916.0
#
#                            CASEBASE5_TOPMINASST  CASEBASE5_TOPAVGASST  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    109807.0             3206501.0
# 0801110002 C0180073                    331062.0             3928758.0
# 0801110003 C94C015B                     80547.0             8675988.0
# 0801110004 C95B0268                    169345.0             5492326.0
# 0801110005 C9840316                    169345.0             5492326.0
#
#                            CASEBASE5_TOPMAXNETWRT  CASEBASE5_TOPMINNETWRT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    31946432.0                 41045.0
# 0801110002 C0180073                     5603209.0                169327.0
# 0801110003 C94C015B                   247965702.0                  6482.0
# 0801110004 C95B0268                    40416702.0                 32815.0
# 0801110005 C9840316                    40416702.0                 32815.0
#
#                            CASEBASE5_TOPAVGNETWRT  Flag_has_emplnum  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     2167368.0                 1
# 0801110002 C0180073                     1904907.0                 1
# 0801110003 C94C015B                     5597523.0                 1
# 0801110004 C95B0268                     3418253.0                 1
# 0801110005 C9840316                     3418253.0                 1
#
#                            Y_OPERATE1  Y_OPERATE2  Y_OPERATE3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780          805638.0    701387.0    630159.0
# 0801110002 C0180073           31993.0     47175.0    221621.0
# 0801110003 C94C015B         3797860.0   3839219.0   3644644.0
# 0801110004 C95B0268         2736536.0   1882370.0   1757860.0
# 0801110005 C9840316         1908341.0   2087679.0   2574067.0
#
#                            Flag_has_operate1  Flag_CEMPL  Flag_CFINSTATE1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        1           1                2
# 0801110002 C0180073                        1           1                2
# 0801110003 C94C015B                        1           2                2
# 0801110004 C95B0268                        1           2                2
# 0801110005 C9840316                        1           2                2
#
#                            CASE_Y  CASE_M CASEBASE_BUSTYPE_4
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780             8       1               1299
# 0801110002 C0180073             8       1               1404
# 0801110003 C94C015B             8       1               1299
# 0801110004 C95B0268             8       1               1212
# 0801110005 C9840316             8       1               1212

# %%
Data.shape
# Out:
# (127747, 551)

# %%
## 抓取 Columns 分類

path = f_PathFileName(Inputfolder,'Data_final_col_summary.xlsx')

col_type = pd.read_excel(path,usecols=[0,1])

col_object = col_type.loc[col_type.iloc[:,1]=='cat']['ColumnsName'].to_list()
col_numeric = col_type.loc[col_type.iloc[:,1]=='num']['ColumnsName'].to_list()

# %% [markdown]
# # 模型納入之欄位

# %%
y_col = ['Y_OPERATE1','CASEBASE1_GPY1']

Data_Y = Data[y_col]
Data_X = Data.drop(columns = y_col)

# %%
# ## 只將「中文」形式挑選出來 

# col = Data_X.columns
# col_suffix_unique = (col.str.extract(r'(.*)(_[EC])(.*)')[0] + '_[EC]?' + col.str.extract(r'(.*)(_[EC])(.*)')[2]).dropna().unique()
# drop_CE = []
# keep_CE = []
# for i in col_suffix_unique:
    
#     bool_contain = col.str.contains(r'^'+i+'$')
#     n_contain = bool_contain.sum()
    
#     if n_contain > 1:
#         if i.replace('_[EC]?','_C') in col:
#             str_find = i.replace('_[EC]?','_C')
#             col_temp = col[bool_contain]
#             col_drop = col_temp[col_temp.str.find(str_find) != 0].to_list()

#         elif i.replace('_[EC]?','_') in col:
#             str_find = i.replace('_[EC]?','_')
#             col_temp = col[bool_contain]
#             col_drop = col_temp[col_temp.str.find(str_find) != 0].to_list()

#         else:
#             print('no {} and {} columnames'.format(i.replace('_[EC]?','_C'),i.replace('_[EC]?','_')))

#         keep_CE.append(str_find)
#         drop_CE = drop_CE + col_drop
    
# print('有相同意義不同語言種類共有：{}'.format(len(keep_CE)))
# print('此步驟共刪除了 {} 個欄位'.format(len(drop_CE)))

# %%
## 不納入 後來評分的欄位之 相關變數：包含 SCORE & RISK

Card_limit = 500
missing_ratio = 0.1
zero_ratio = 0.9
Corr = 0.95
keep = ['Y_OPERATE2','CASEBASE5_TOPNOWCAP','CASEBASE5_TOPNOWNETWRT','CASEBASE5_TOPYEAR','CASEBASE5_TOPMAXBUSSORT','CASEBASE5_TOPNOWBUSSORT','CASEFINANCIAL_1_FINDATE1']
drop_set = ['CASEBASE5_TOPNOWSALE','CASEBASE5_TOPBUSID','CASEBASE5_FINANCEBUSID']

condi = {Card_limit: lambda x : f_DropHighCard(Data_X,x,keep = keep),  # 刪除型態為 Object ，unique 數目較多的欄位
         #Corr: lambda x : f_DropHighCorr(Data_X,x,keep = keep),
         1: lambda x : f_DropIdentity(Data_X,x,keep = keep),
         zero_ratio : lambda x : f_DropZero(Data_X,x,keep = keep),     # 刪除 zero 比例高於9成資料
         missing_ratio: lambda x : f_DropNa2(Data_X,x,keep = keep)}    # 刪除 Missing value 比例高於 0.1 的資料

# %%
## 把抓出有 Score 的欄位
ColDropTable, drop= f_DropColPipe(condi, regex = True)
ColDropTable
#drop_score
# Out:
# 需刪除欄位共:382
#              Symbol                                         ColumnName  Total  \
# 0  DropHighCard 500  [CASEBASE_CPCN1, CASEBASE_CPEN1, CASEBASE_BILL...    549
# 1     Drop Identity  [CASEBASE_CCAPCURR, CASEBASE1_CCAPTDOLL, CASEB...    549
# 2      DropZero 0.9  [CASEBASE_OPENINGTIME, CASEBASE1_COOPEIN, CASE...    549
# 3        DropNA 0.1  [CASEBASE_CEMPL, CASEBASE_CPJN1, CASEBASE_LICE...    549
#
#    符合該條件數目  符合該條件,需保留的  最終刪數目     刪除百分比
# 0       79           0     79  0.143898
# 1       15           0     15  0.027322
# 2       32           0     32  0.058288
# 3      332           1    331  0.602914

# %%
## 首先，先將「重複意義欄位」以及缺值大於 0.1 的欄位做刪除。

drop_temp =  ColDropTable.loc[:,:]['ColumnName'].sum()
Data2 = Data.drop(columns = drop_temp)
Data2.shape
# Out:
# (127747, 169)

# %%
corr_matrix = Data2.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
combine = set()
for i in corr_matrix.columns:
    temp_col = corr_matrix[corr_matrix[i]>Corr].index.to_list()
    if len(temp_col) <= 1 or (tuple(temp_col) in combine):
        continue
    else:
        
        cm = corr_matrix.loc[temp_col,temp_col].values
        plt.figure(figsize = (5,5))
        sns.set(font_scale=1.5)
        hm = sns.heatmap(cm,
                         cbar=True,
                         annot=True,
                         square=True,
                         fmt='.2f',
                         annot_kws={'size': 10},
                         yticklabels=temp_col,
                         xticklabels=temp_col)
        plt.show() 
        combine = combine | {tuple(temp_col)}

# %%
ColDropTable_corr, drop_corr= f_DropColPipe({Corr: lambda x : f_DropHighCorr(Data2,x,keep = y_col + keep)}, regex = True)
ColDropTable_corr
drop_corr
# Out:
# 需刪除欄位共:12
#         Symbol                                         ColumnName  Total  \
# 0  Corr > 0.95  [CASEBASE_REGISTMONEY, CASEFINANCIAL_2_FINDATE...    169
#
#    符合該條件數目  符合該條件,需保留的  最終刪數目     刪除百分比
# 0       14           2     12  0.071006
# ['CASEBASE_REGISTMONEY',
#  'CASEFINANCIAL_2_FINDATE1',
#  'CASEFINANCIAL_1_FINDATE2',
#  'CASEFINANCIAL_2_FINDATE2',
#  'CASEFINANCIAL_2_FINDATE3',
#  'CASEBASE5_TOPTOTALM',
#  'CASEBASE5_TOPMAXSORT',
#  'CASEBASE5_TOPNOWSORT',
#  'CASEBASE5_TOPNOWEMP',
#  'CASEBASE5_TOPNOWSALE',
#  'CASEBASE5_FINACEYEAR',
#  'CASEBASE5_FINANCEBUSID']

# %% [markdown]
# # 納入模型

# %%
Data2 = Data.drop(columns = drop_set + drop + drop_corr )
Data2.shape
# Out:
# (127747, 156)

# %%
Data2.head()
# Out:
#                            CASEBASE_EMPLNUM  CASEBASE_BUILDATE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     101               24.0
# 0801110002 C0180073                      50               23.0
# 0801110003 C94C015B                     160               27.0
# 0801110004 C95B0268                     759               30.0
# 0801110005 C9840316                     632               23.0
#
#                           CASEBASE_CCOMPTYPE CASEBASE_CBUSKIND CASEBASE_RANK  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     大型企業               製造業             B
# 0801110002 C0180073                     中型企業               製造業             B
# 0801110003 C94C015B                     大型企業               製造業             B
# 0801110004 C95B0268                     大型企業               製造業             B
# 0801110005 C9840316                     大型企業               製造業             B
#
#                            CASEBASE_LEGAL CASEBASE_CCOUNTYOE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   1.0                桃園縣
# 0801110002 C0180073                   1.0                台中市
# 0801110003 C94C015B                   1.0                桃園縣
# 0801110004 C95B0268                   1.0                台北市
# 0801110005 C9840316                   1.0                高雄縣
#
#                            CASEBASE1_FACTORY  CASEBASE1_CONGLOME  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      2.0                 5.0
# 0801110002 C0180073                      2.0                 0.0
# 0801110003 C94C015B                      1.0                13.0
# 0801110004 C95B0268                      3.0                 6.0
# 0801110005 C9840316                      2.0                 8.0
#
#                            CASEBASE1_HISTYPE  CASEBASE1_HISTORY  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      1.0                1.0
# 0801110002 C0180073                      1.0                1.0
# 0801110003 C94C015B                      1.0                1.0
# 0801110004 C95B0268                      1.0                1.0
# 0801110005 C9840316                      0.0                0.0
#
#                            CASEBASE1_SALEITEM  CASEBASE1_CAPTIAL  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       2.0                9.0
# 0801110002 C0180073                       1.0                9.0
# 0801110003 C94C015B                       2.0               10.0
# 0801110004 C95B0268                       1.0                8.0
# 0801110005 C9840316                       1.0               12.0
#
#                            CASEBASE1_STOCKER  CASEBASE1_STOCKH  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      0.0              10.0
# 0801110002 C0180073                      0.0              10.0
# 0801110003 C94C015B                      0.0               9.0
# 0801110004 C95B0268                      0.0              13.0
# 0801110005 C9840316                      0.0              10.0
#
#                            CASEBASE1_OPERATE  CASEBASE1_MPLANT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      1.0               1.0
# 0801110002 C0180073                      2.0               1.0
# 0801110003 C94C015B                      2.0               1.0
# 0801110004 C95B0268                      1.0               2.0
# 0801110005 C9840316                      1.0               1.0
#
#                            CASEBASE1_PROCPLANT  CASEBASE1_PAWN  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        0.0             1.0
# 0801110002 C0180073                        3.0             0.0
# 0801110003 C94C015B                        1.0             0.0
# 0801110004 C95B0268                        6.0             1.0
# 0801110005 C9840316                       10.0             1.0
#
#                            CASEBASE1_RATEY1  CASEBASE1_RATEY2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   100.0             100.0
# 0801110002 C0180073                   100.0             100.0
# 0801110003 C94C015B                   100.0             100.0
# 0801110004 C95B0268                   100.0             100.0
# 0801110005 C9840316                   100.0             100.0
#
#                            CASEBASE1_RATEY3  CASEBASE1_GPY1  CASEBASE1_GPY2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   100.0           14.86           11.30
# 0801110002 C0180073                   100.0          -32.18          -78.71
# 0801110003 C94C015B                   100.0           -1.08            5.34
# 0801110004 C95B0268                   100.0           45.38            7.08
# 0801110005 C9840316                   100.0           -8.59          -18.90
#
#                            CASEBASE1_OPENYEAR  CASEBASE1_SALESTAT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       2.0                 3.0
# 0801110002 C0180073                       2.0                 3.0
# 0801110003 C94C015B                       3.0                 1.0
# 0801110004 C95B0268                       2.0                 4.0
# 0801110005 C9840316                       2.0                 3.0
#
#                            CASEBASE1_STUFFIN  CASEBASE1_STLC  CASEBASE1_STTT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      7.0             0.0             0.0
# 0801110002 C0180073                      1.0           100.0             0.0
# 0801110003 C94C015B                     11.0            10.0            90.0
# 0801110004 C95B0268                      6.0             0.0           100.0
# 0801110005 C9840316                      8.0            50.0            50.0
#
#                            CASEBASE1_STOTHER  CASEBASE1_STUFFOUT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    100.0                 1.0
# 0801110002 C0180073                      0.0                 2.0
# 0801110003 C94C015B                      0.0                 2.0
# 0801110004 C95B0268                      0.0                 2.0
# 0801110005 C9840316                      0.0                 1.0
#
#                           CASEBASE1_CORGTYPE  CASEBASE1_ONEEXPLAIN  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     股票上櫃                   1.0
# 0801110002 C0180073                     興櫃股票                   0.0
# 0801110003 C94C015B                     股票上櫃                   1.0
# 0801110004 C95B0268                     興櫃股票                   0.0
# 0801110005 C9840316                     股票上市                   0.0
#
#                            CASEBASE1_OPEOFFER_SEX  CASEBASE2_STUFFIN2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                           0.0                 0.0
# 0801110002 C0180073                           0.0                 2.0
# 0801110003 C94C015B                           0.0                 6.0
# 0801110004 C95B0268                           0.0                 5.0
# 0801110005 C9840316                           0.0                10.0
#
#                            CASEBASE2_PSLC  CASEBASE2_PSTT  CASEBASE2_PSOTHER  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   0.0             0.0              100.0
# 0801110002 C0180073                 100.0             0.0                0.0
# 0801110003 C94C015B                   0.0           100.0                0.0
# 0801110004 C95B0268                   0.0           100.0                0.0
# 0801110005 C9840316                  50.0            50.0                0.0
#
#                            CASEBASE2_STUFFOUT2  CASEBASE2_BANK  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        1.0             0.0
# 0801110002 C0180073                        2.0             2.0
# 0801110003 C94C015B                        1.0             1.0
# 0801110004 C95B0268                        4.0             2.0
# 0801110005 C9840316                        1.0             2.0
#
#                           CASEBASE2_BILL1 CASEBASE2_BILL2 CASEBASE2_BILL3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     N               Y               Y
# 0801110002 C0180073                     N               N               N
# 0801110003 C94C015B                     N               N               N
# 0801110004 C95B0268                     N               N               Y
# 0801110005 C9840316                     N               N               Y
#
#                            CASEBASE2_PRESBILL CASEBASE2_REFUND0  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       1.0                 Y
# 0801110002 C0180073                       0.0               NaN
# 0801110003 C94C015B                       0.0                 Y
# 0801110004 C95B0268                       0.0                 Y
# 0801110005 C9840316                       0.0                 Y
#
#                           CASEBASE2_REFUND1 CASEBASE2_REFUND2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       N                 N
# 0801110002 C0180073                     NaN               NaN
# 0801110003 C94C015B                       Y                 Y
# 0801110004 C95B0268                       N                 Y
# 0801110005 C9840316                       N                 Y
#
#                           CASEBASE2_REFUND3 CASEBASE2_REFUND4  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       N                 Y
# 0801110002 C0180073                     NaN                 Y
# 0801110003 C94C015B                       Y                 Y
# 0801110004 C95B0268                       Y                 Y
# 0801110005 C9840316                       Y                 Y
#
#                            CASEBASE2_LAWSUITREC  CASEBASE2_LAWSUIT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         0.0                0.0
# 0801110002 C0180073                         1.0                1.0
# 0801110003 C94C015B                         1.0                1.0
# 0801110004 C95B0268                         1.0                2.0
# 0801110005 C9840316                         1.0                2.0
#
#                            CASEBASE2_PATENT  CASEBASE2_PANTENTNO  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     0.0                  0.0
# 0801110002 C0180073                     1.0                  4.0
# 0801110003 C94C015B                     1.0                 13.0
# 0801110004 C95B0268                     0.0                  0.0
# 0801110005 C9840316                     1.0                  7.0
#
#                            CASEBASE2_PLACELIST  CASEBASE2_PLACENUM  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        0.0                 0.0
# 0801110002 C0180073                        0.0                 0.0
# 0801110003 C94C015B                        0.0                 0.0
# 0801110004 C95B0268                        0.0                 0.0
# 0801110005 C9840316                        0.0                 0.0
#
#                            CASEBASE2_EPLIST  CASEBASE2_INOUT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     5.0              2.0
# 0801110002 C0180073                     5.0              2.0
# 0801110003 C94C015B                     5.0              2.0
# 0801110004 C95B0268                     5.0              3.0
# 0801110005 C9840316                     5.0              3.0
#
#                            CASEBASE2_FINANCIAL  CASEBASE2_FINSTATE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        8.0                 0.0
# 0801110002 C0180073                        8.0                 0.0
# 0801110003 C94C015B                        8.0                 0.0
# 0801110004 C95B0268                        8.0                 0.0
# 0801110005 C9840316                        8.0                 0.0
#
#                           CASEBASE2_TAXTYPE CASEBASE2_CPATYPE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       N                 Y
# 0801110002 C0180073                       N                 Y
# 0801110003 C94C015B                       N                 Y
# 0801110004 C95B0268                       N                 Y
# 0801110005 C9840316                       N                 Y
#
#                           CASEBASE2_COMPTYPE  CASEBASE2_NEWS  CASEBASE2_BASIS  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        N             0.0              9.0
# 0801110002 C0180073                        N             0.0              9.0
# 0801110003 C94C015B                        N             4.0              9.0
# 0801110004 C95B0268                        N             2.0              9.0
# 0801110005 C9840316                        N             5.0              0.0
#
#                           CASEBASE2_PROPOSAL  CASEBASE2_RPTTYPE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        Z                2.0
# 0801110002 C0180073                        Z                2.0
# 0801110003 C94C015B                        Z                2.0
# 0801110004 C95B0268                        Z                2.0
# 0801110005 C9840316                        Z                2.0
#
#                           CASEBASE2_NOFINRPT CASEBASE2_MAXCREDIT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        N                   N
# 0801110002 C0180073                        N                   N
# 0801110003 C94C015B                        N                   N
# 0801110004 C95B0268                        N                   Y
# 0801110005 C9840316                        N                   Y
#
#                           CASEBASE2_PROCREDIT  CASEBASE2_NGETMSTOCK  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         N                   0.0
# 0801110002 C0180073                         N                   0.0
# 0801110003 C94C015B                         N                   0.0
# 0801110004 C95B0268                         N                   0.0
# 0801110005 C9840316                         N                   0.0
#
#                           CASEBASE3_FINCHK  CASEBASE3_NLIQUTRAN  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      Y                  0.0
# 0801110002 C0180073                      Y                  0.0
# 0801110003 C94C015B                      Y                  NaN
# 0801110004 C95B0268                      Y                  0.0
# 0801110005 C9840316                      Y                  0.0
#
#                            CASEBASE3_OPERTRAN  CASEBASE3_CHFOLW1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      0.55                0.0
# 0801110002 C0180073                      0.17                1.0
# 0801110003 C94C015B                      1.23                0.0
# 0801110004 C95B0268                      0.99                0.0
# 0801110005 C9840316                      0.74                1.0
#
#                            CASEBASE3_CHFOLW1AMT  CASEBASE3_CHFOLW2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     82671.0                0.0
# 0801110002 C0180073                     75385.0                0.0
# 0801110003 C94C015B                    204255.0                1.0
# 0801110004 C95B0268                     56590.0                1.0
# 0801110005 C9840316                     44714.0                1.0
#
#                            CASEBASE3_ANAYYEAR  CASEBASE3_LIQUVER  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    2006.0                1.0
# 0801110002 C0180073                    2006.0                1.0
# 0801110003 C94C015B                    2006.0                1.0
# 0801110004 C95B0268                    2006.0                1.0
# 0801110005 C9840316                    2006.0                1.0
#
#                            CASEBASE3_CASHVER  CASEFINANCIAL_1_FINDATE1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      1.0                  626578.0
# 0801110002 C0180073                      1.0                  295000.0
# 0801110003 C94C015B                      1.0                 1370000.0
# 0801110004 C95B0268                      1.0                  900000.0
# 0801110005 C9840316                      1.0                 1191258.0
#
#                            CASEFINANCIAL_8_FINDATE1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          2006.0
# 0801110002 C0180073                          2006.0
# 0801110003 C94C015B                          2006.0
# 0801110004 C95B0268                          2006.0
# 0801110005 C9840316                          2006.0
#
#                            CASEFINANCIAL_10_FINDATE1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          46187.0
# 0801110002 C0180073                          26730.0
# 0801110003 C94C015B                         251705.0
# 0801110004 C95B0268                         299666.0
# 0801110005 C9840316                          32474.0
#
#                            CASEFINANCIAL_11_FINDATE1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          20614.0
# 0801110002 C0180073                          33489.0
# 0801110003 C94C015B                         216010.0
# 0801110004 C95B0268                         131824.0
# 0801110005 C9840316                          56791.0
#
#                            CASEFINANCIAL_10_FINDATE2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          84964.0
# 0801110002 C0180073                          52588.0
# 0801110003 C94C015B                         412900.0
# 0801110004 C95B0268                          75907.0
# 0801110005 C9840316                          25230.0
#
#                            CASEFINANCIAL_11_FINDATE2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          75934.0
# 0801110002 C0180073                          56525.0
# 0801110003 C94C015B                         240074.0
# 0801110004 C95B0268                          25509.0
# 0801110005 C9840316                         251084.0
#
#                            CASEFINANCIAL_1_FINDATE3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        324104.0
# 0801110002 C0180073                        200000.0
# 0801110003 C94C015B                       1024000.0
# 0801110004 C95B0268                        565600.0
# 0801110005 C9840316                        903880.0
#
#                            CASEFINANCIAL_10_FINDATE3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          98327.0
# 0801110002 C0180073                          10477.0
# 0801110003 C94C015B                         400135.0
# 0801110004 C95B0268                         307793.0
# 0801110005 C9840316                         370590.0
#
#                            CASEFINANCIAL_11_FINDATE3  CASEINOUT_3_INOUT1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          77942.0                 1.0
# 0801110002 C0180073                           3678.0                 0.5
# 0801110003 C94C015B                         309748.0                 3.0
# 0801110004 C95B0268                         204303.0                 2.5
# 0801110005 C9840316                         268107.0                 8.5
#
#                            LAND_AREA_SUM  BUILD_AREA_SUM  CASEBASE5_TOPYEAR  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780              5773.00         6073.00             2008.0
# 0801110002 C0180073              2446.64         1898.54             2007.0
# 0801110003 C94C015B              1819.00        11240.00             2007.0
# 0801110004 C95B0268              7272.00         7901.00             2007.0
# 0801110005 C9840316              4001.00         7499.00             2007.0
#
#                           CASEBASE5_TOPBUSNAME CASEBASE5_ATTRIBUTE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    被動電子元件業                   M
# 0801110002 C0180073                        電池業                   M
# 0801110003 C94C015B                   其他電子零組件業                   M
# 0801110004 C95B0268                     印刷電路板業                   M
# 0801110005 C9840316                     印刷電路板業                   M
#
#                           CASEBASE5_ATTRIBNAME  CASEBASE5_TOPBUSSUMM  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        製造業                2746.0
# 0801110002 C0180073                        製造業                2709.0
# 0801110003 C94C015B                        製造業                2709.0
# 0801110004 C95B0268                        製造業                2709.0
# 0801110005 C9840316                        製造業                2709.0
#
#                            CASEBASE5_TOPBUSSUM  CASEBASE5_COMPBUSNO  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       63.0                 37.0
# 0801110002 C0180073                       17.0                  0.0
# 0801110003 C94C015B                      116.0                 19.0
# 0801110004 C95B0268                       75.0                 25.0
# 0801110005 C9840316                       75.0                 32.0
#
#                            CASEBASE5_TOPAVGEMP  CASEBASE5_TOPAVGSALE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      288.0             2041684.0
# 0801110002 C0180073                      295.0             3510459.0
# 0801110003 C94C015B                      470.0             5529818.0
# 0801110004 C95B0268                      793.0             4943723.0
# 0801110005 C9840316                      793.0             4943723.0
#
#                            CASEBASE5_TOPMINSORT  CASEBASE5_TOPMAXBUSSORT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      4921.0                    156.0
# 0801110002 C0180073                      4326.0                    116.0
# 0801110003 C94C015B                      4783.0                     12.0
# 0801110004 C95B0268                      4855.0                     41.0
# 0801110005 C9840316                      4855.0                     41.0
#
#                            CASEBASE5_TOPMINBUSSORT  CASEBASE5_TOPNOWBUSSORT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         2703.0                   1513.0
# 0801110002 C0180073                         2464.0                      0.0
# 0801110003 C94C015B                         2652.0                    468.0
# 0801110004 C95B0268                         2680.0                    623.0
# 0801110005 C9840316                         2680.0                    826.0
#
#                            CASEBASE5_TOPMAXEMP  CASEBASE5_TOPMINEMP  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     2586.0                 15.0
# 0801110002 C0180073                      905.0                 50.0
# 0801110003 C94C015B                    13322.0                 10.0
# 0801110004 C95B0268                     5985.0                 40.0
# 0801110005 C9840316                     5985.0                 40.0
#
#                            CASEBASE5_TOPMAXSALE  CASEBASE5_TOPMINSALE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  13165645.0              125298.0
# 0801110002 C0180073                  16310066.0              220540.0
# 0801110003 C94C015B                 181652407.0              129934.0
# 0801110004 C95B0268                  49801871.0              115900.0
# 0801110005 C9840316                  49801871.0              115900.0
#
#                            CASEBASE5_NOWSALEY  CASEBASE5_TOPMAXCAP  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    2006.0           24382213.0
# 0801110002 C0180073                    2006.0            2036188.0
# 0801110003 C94C015B                    2006.0           76235909.0
# 0801110004 C95B0268                    2006.0           12071291.0
# 0801110005 C9840316                    2006.0           12071291.0
#
#                            CASEBASE5_TOPMINCAP  CASEBASE5_TOPNOWCAP  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    50000.0             756997.0
# 0801110002 C0180073                    54000.0             385000.0
# 0801110003 C94C015B                    20000.0            1504000.0
# 0801110004 C95B0268                    40660.0            1075290.0
# 0801110005 C9840316                    40660.0            1193121.0
#
#                            CASEBASE5_FINACETYPE CASEBASE5_FINANCEBUSNAME  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         1.0                 其他電子零組件業
# 0801110002 C0180073                         1.0                      電池業
# 0801110003 C94C015B                         1.0                 其他電子零組件業
# 0801110004 C95B0268                         1.0                   印刷電路板業
# 0801110005 C9840316                         1.0                   印刷電路板業
#
#                            CASEBASE5_MED02  CASEBASE5_MED06  CASEBASE5_MED09  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  12.39            35.57           535.19
# 0801110002 C0180073                  17.99            41.06           400.88
# 0801110003 C94C015B                  14.64            39.11           475.16
# 0801110004 C95B0268                  25.62            42.15           258.91
# 0801110005 C9840316                  25.62            42.15           258.91
#
#                            CASEBASE5_MED10  CASEBASE5_MED23  CASEBASE5_MED24  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  55.14             6.48            10.61
# 0801110002 C0180073                   0.00             5.34            11.99
# 0801110003 C94C015B                   0.00             6.00             9.80
# 0801110004 C95B0268                   0.00             7.21            11.46
# 0801110005 C9840316                   0.00             7.21            11.46
#
#                            CASEBASE5_MED25  CASEBASE5_MED26  CASEBASE5_MED41  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   6.72            18.54             9.32
# 0801110002 C0180073                   6.03            37.86             6.10
# 0801110003 C94C015B                   6.30            18.54             7.80
# 0801110004 C95B0268                   7.51            20.97             9.05
# 0801110005 C9840316                   7.51            20.97             9.05
#
#                            CASEBASE5_MED42  CASEBASE5_MED43  CASEBASE5_MED45  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   3.42             6.21             0.86
# 0801110002 C0180073                   4.55             5.87             0.83
# 0801110003 C94C015B                   3.52             5.34             0.81
# 0801110004 C95B0268                   3.11             2.96             0.80
# 0801110005 C9840316                   3.11             2.96             0.80
#
#                            CASEBASE5_MED50  CASEBASE5_MED51  CASEBASE5_MED61  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   5.36             68.0           186.26
# 0801110002 C0180073                   6.36             58.0           179.61
# 0801110003 C94C015B                   5.09             72.0           165.80
# 0801110004 C95B0268                   4.90             75.0           145.34
# 0801110005 C9840316                   4.90             75.0           145.34
#
#                            CASEBASE5_MED62  CASEBASE5_MED64  CASEBASE5_MED65  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                 146.38            37.22           108.44
# 0801110002 C0180073                 123.03            60.55            81.42
# 0801110003 C94C015B                 137.10            45.57           105.28
# 0801110004 C95B0268                 116.54            40.01           119.25
# 0801110005 C9840316                 116.54            40.01           119.25
#
#                            CASEBASE5_MED67  CASEBASE5_MED71  CASEBASE5_MED72  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  14.02            12.77             4.94
# 0801110002 C0180073                  15.60             5.49             0.13
# 0801110003 C94C015B                  14.04            19.67             7.22
# 0801110004 C95B0268                  15.97            21.92             6.55
# 0801110005 C9840316                  15.97            21.92             6.55
#
#                            CASEBASE5_MED22  CASEBASE5_MED21  CASEBASE5_MED44  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    0.0              0.0              0.0
# 0801110002 C0180073                    0.0              0.0              0.0
# 0801110003 C94C015B                    0.0              0.0              0.0
# 0801110004 C95B0268                    0.0              0.0              0.0
# 0801110005 C9840316                    0.0              0.0              0.0
#
#                            CASEBASE5_REC_NO  CASEBASE5_MEMPLID  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   160.0              546.0
# 0801110002 C0180073                    10.0              982.0
# 0801110003 C94C015B                   146.0              546.0
# 0801110004 C95B0268                    60.0              982.0
# 0801110005 C9840316                    60.0              982.0
#
#                            CASEBASE5_TOPAVGCAP  CASEBASE5_TOPNOWASST  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  1236431.0             1811326.0
# 0801110002 C0180073                   801170.0              196029.0
# 0801110003 C94C015B                  1955412.0             3143217.0
# 0801110004 C95B0268                  1608159.0             2879075.0
# 0801110005 C9840316                  1608159.0             2526886.0
#
#                            CASEBASE5_TOPNOWNETWRT  CASEBASE5_TOPMAXASST  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      852689.0            49603313.0
# 0801110002 C0180073                      125566.0             9136650.0
# 0801110003 C94C015B                     2021511.0           374446256.0
# 0801110004 C95B0268                     1199624.0            47779916.0
# 0801110005 C9840316                     1291005.0            47779916.0
#
#                            CASEBASE5_TOPMINASST  CASEBASE5_TOPAVGASST  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    109807.0             3206501.0
# 0801110002 C0180073                    331062.0             3928758.0
# 0801110003 C94C015B                     80547.0             8675988.0
# 0801110004 C95B0268                    169345.0             5492326.0
# 0801110005 C9840316                    169345.0             5492326.0
#
#                            CASEBASE5_TOPMAXNETWRT  CASEBASE5_TOPMINNETWRT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    31946432.0                 41045.0
# 0801110002 C0180073                     5603209.0                169327.0
# 0801110003 C94C015B                   247965702.0                  6482.0
# 0801110004 C95B0268                    40416702.0                 32815.0
# 0801110005 C9840316                    40416702.0                 32815.0
#
#                            CASEBASE5_TOPAVGNETWRT  Flag_has_emplnum  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     2167368.0                 1
# 0801110002 C0180073                     1904907.0                 1
# 0801110003 C94C015B                     5597523.0                 1
# 0801110004 C95B0268                     3418253.0                 1
# 0801110005 C9840316                     3418253.0                 1
#
#                            Y_OPERATE1  Y_OPERATE2  Flag_CEMPL  CASE_Y  CASE_M  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780          805638.0    701387.0           1       8       1
# 0801110002 C0180073           31993.0     47175.0           1       8       1
# 0801110003 C94C015B         3797860.0   3839219.0           2       8       1
# 0801110004 C95B0268         2736536.0   1882370.0           2       8       1
# 0801110005 C9840316         1908341.0   2087679.0           2       8       1
#
#                           CASEBASE_BUSTYPE_4
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     1299
# 0801110002 C0180073                     1404
# 0801110003 C94C015B                     1299
# 0801110004 C95B0268                     1212
# 0801110005 C9840316                     1212

# %%
ms.matrix(Data2)
# Out:
# <AxesSubplot:>

# %%
Data2.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 127747 entries, ('0801110001', 'C0460780') to ('1905990029', 'C941005F')
# Data columns (total 156 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   CASEBASE_EMPLNUM           int64
#  1   CASEBASE_BUILDATE          float64
#  2   CASEBASE_CCOMPTYPE         object
#  3   CASEBASE_CBUSKIND          object
#  4   CASEBASE_RANK              object
#  5   CASEBASE_LEGAL             float64
#  6   CASEBASE_CCOUNTYOE         object
#  7   CASEBASE1_FACTORY          float64
#  8   CASEBASE1_CONGLOME         float64
#  9   CASEBASE1_HISTYPE          float64
#  10  CASEBASE1_HISTORY          float64
#  11  CASEBASE1_SALEITEM         float64
#  12  CASEBASE1_CAPTIAL          float64
#  13  CASEBASE1_STOCKER          float64
#  14  CASEBASE1_STOCKH           float64
#  15  CASEBASE1_OPERATE          float64
#  16  CASEBASE1_MPLANT           float64
#  17  CASEBASE1_PROCPLANT        float64
#  18  CASEBASE1_PAWN             float64
#  19  CASEBASE1_RATEY1           float64
#  20  CASEBASE1_RATEY2           float64
#  21  CASEBASE1_RATEY3           float64
#  22  CASEBASE1_GPY1             float64
#  23  CASEBASE1_GPY2             float64
#  24  CASEBASE1_OPENYEAR         float64
#  25  CASEBASE1_SALESTAT         float64
#  26  CASEBASE1_STUFFIN          float64
#  27  CASEBASE1_STLC             float64
#  28  CASEBASE1_STTT             float64
#  29  CASEBASE1_STOTHER          float64
#  30  CASEBASE1_STUFFOUT         float64
#  31  CASEBASE1_CORGTYPE         object
#  32  CASEBASE1_ONEEXPLAIN       float64
#  33  CASEBASE1_OPEOFFER_SEX     float64
#  34  CASEBASE2_STUFFIN2         float64
#  35  CASEBASE2_PSLC             float64
#  36  CASEBASE2_PSTT             float64
#  37  CASEBASE2_PSOTHER          float64
#  38  CASEBASE2_STUFFOUT2        float64
#  39  CASEBASE2_BANK             float64
#  40  CASEBASE2_BILL1            object
#  41  CASEBASE2_BILL2            object
#  42  CASEBASE2_BILL3            object
#  43  CASEBASE2_PRESBILL         float64
#  44  CASEBASE2_REFUND0          object
#  45  CASEBASE2_REFUND1          object
#  46  CASEBASE2_REFUND2          object
#  47  CASEBASE2_REFUND3          object
#  48  CASEBASE2_REFUND4          object
#  49  CASEBASE2_LAWSUITREC       float64
#  50  CASEBASE2_LAWSUIT          float64
#  51  CASEBASE2_PATENT           float64
#  52  CASEBASE2_PANTENTNO        float64
#  53  CASEBASE2_PLACELIST        float64
#  54  CASEBASE2_PLACENUM         float64
#  55  CASEBASE2_EPLIST           float64
#  56  CASEBASE2_INOUT            float64
#  57  CASEBASE2_FINANCIAL        float64
#  58  CASEBASE2_FINSTATE         float64
#  59  CASEBASE2_TAXTYPE          object
#  60  CASEBASE2_CPATYPE          object
#  61  CASEBASE2_COMPTYPE         object
#  62  CASEBASE2_NEWS             float64
#  63  CASEBASE2_BASIS            float64
#  64  CASEBASE2_PROPOSAL         object
#  65  CASEBASE2_RPTTYPE          float64
#  66  CASEBASE2_NOFINRPT         object
#  67  CASEBASE2_MAXCREDIT        object
#  68  CASEBASE2_PROCREDIT        object
#  69  CASEBASE2_NGETMSTOCK       float64
#  70  CASEBASE3_FINCHK           object
#  71  CASEBASE3_NLIQUTRAN        float64
#  72  CASEBASE3_OPERTRAN         float64
#  73  CASEBASE3_CHFOLW1          float64
#  74  CASEBASE3_CHFOLW1AMT       float64
#  75  CASEBASE3_CHFOLW2          float64
#  76  CASEBASE3_ANAYYEAR         float64
#  77  CASEBASE3_LIQUVER          float64
#  78  CASEBASE3_CASHVER          float64
#  79  CASEFINANCIAL_1_FINDATE1   float64
#  80  CASEFINANCIAL_8_FINDATE1   float64
#  81  CASEFINANCIAL_10_FINDATE1  float64
#  82  CASEFINANCIAL_11_FINDATE1  float64
#  83  CASEFINANCIAL_10_FINDATE2  float64
#  84  CASEFINANCIAL_11_FINDATE2  float64
#  85  CASEFINANCIAL_1_FINDATE3   float64
#  86  CASEFINANCIAL_10_FINDATE3  float64
#  87  CASEFINANCIAL_11_FINDATE3  float64
#  88  CASEINOUT_3_INOUT1         float64
#  89  LAND_AREA_SUM              float64
#  90  BUILD_AREA_SUM             float64
#  91  CASEBASE5_TOPYEAR          float64
#  92  CASEBASE5_TOPBUSNAME       object
#  93  CASEBASE5_ATTRIBUTE        object
#  94  CASEBASE5_ATTRIBNAME       object
#  95  CASEBASE5_TOPBUSSUMM       float64
#  96  CASEBASE5_TOPBUSSUM        float64
#  97  CASEBASE5_COMPBUSNO        float64
#  98  CASEBASE5_TOPAVGEMP        float64
#  99  CASEBASE5_TOPAVGSALE       float64
#  100 CASEBASE5_TOPMINSORT       float64
#  101 CASEBASE5_TOPMAXBUSSORT    float64
#  102 CASEBASE5_TOPMINBUSSORT    float64
#  103 CASEBASE5_TOPNOWBUSSORT    float64
#  104 CASEBASE5_TOPMAXEMP        float64
#  105 CASEBASE5_TOPMINEMP        float64
#  106 CASEBASE5_TOPMAXSALE       float64
#  107 CASEBASE5_TOPMINSALE       float64
#  108 CASEBASE5_NOWSALEY         float64
#  109 CASEBASE5_TOPMAXCAP        float64
#  110 CASEBASE5_TOPMINCAP        float64
#  111 CASEBASE5_TOPNOWCAP        float64
#  112 CASEBASE5_FINACETYPE       float64
#  113 CASEBASE5_FINANCEBUSNAME   object
#  114 CASEBASE5_MED02            float64
#  115 CASEBASE5_MED06            float64
#  116 CASEBASE5_MED09            float64
#  117 CASEBASE5_MED10            float64
#  118 CASEBASE5_MED23            float64
#  119 CASEBASE5_MED24            float64
#  120 CASEBASE5_MED25            float64
#  121 CASEBASE5_MED26            float64
#  122 CASEBASE5_MED41            float64
#  123 CASEBASE5_MED42            float64
#  124 CASEBASE5_MED43            float64
#  125 CASEBASE5_MED45            float64
#  126 CASEBASE5_MED50            float64
#  127 CASEBASE5_MED51            float64
#  128 CASEBASE5_MED61            float64
#  129 CASEBASE5_MED62            float64
#  130 CASEBASE5_MED64            float64
#  131 CASEBASE5_MED65            float64
#  132 CASEBASE5_MED67            float64
#  133 CASEBASE5_MED71            float64
#  134 CASEBASE5_MED72            float64
#  135 CASEBASE5_MED22            float64
#  136 CASEBASE5_MED21            float64
#  137 CASEBASE5_MED44            float64
#  138 CASEBASE5_REC_NO           float64
#  139 CASEBASE5_MEMPLID          float64
#  140 CASEBASE5_TOPAVGCAP        float64
#  141 CASEBASE5_TOPNOWASST       float64
#  142 CASEBASE5_TOPNOWNETWRT     float64
#  143 CASEBASE5_TOPMAXASST       float64
#  144 CASEBASE5_TOPMINASST       float64
#  145 CASEBASE5_TOPAVGASST       float64
#  146 CASEBASE5_TOPMAXNETWRT     float64
#  147 CASEBASE5_TOPMINNETWRT     float64
#  148 CASEBASE5_TOPAVGNETWRT     float64
#  149 Flag_has_emplnum           int64
#  150 Y_OPERATE1                 float64
#  151 Y_OPERATE2                 float64
#  152 Flag_CEMPL                 int64
#  153 CASE_Y                     int64
#  154 CASE_M                     int64
#  155 CASEBASE_BUSTYPE_4         object
# dtypes: float64(125), int64(5), object(26)
# memory usage: 160.2+ MB

# %%
Data2.head()
# Out:
#                            CASEBASE_EMPLNUM  CASEBASE_BUILDATE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     101               24.0
# 0801110002 C0180073                      50               23.0
# 0801110003 C94C015B                     160               27.0
# 0801110004 C95B0268                     759               30.0
# 0801110005 C9840316                     632               23.0
#
#                           CASEBASE_CCOMPTYPE CASEBASE_CBUSKIND CASEBASE_RANK  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     大型企業               製造業             B
# 0801110002 C0180073                     中型企業               製造業             B
# 0801110003 C94C015B                     大型企業               製造業             B
# 0801110004 C95B0268                     大型企業               製造業             B
# 0801110005 C9840316                     大型企業               製造業             B
#
#                            CASEBASE_LEGAL CASEBASE_CCOUNTYOE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   1.0                桃園縣
# 0801110002 C0180073                   1.0                台中市
# 0801110003 C94C015B                   1.0                桃園縣
# 0801110004 C95B0268                   1.0                台北市
# 0801110005 C9840316                   1.0                高雄縣
#
#                            CASEBASE1_FACTORY  CASEBASE1_CONGLOME  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      2.0                 5.0
# 0801110002 C0180073                      2.0                 0.0
# 0801110003 C94C015B                      1.0                13.0
# 0801110004 C95B0268                      3.0                 6.0
# 0801110005 C9840316                      2.0                 8.0
#
#                            CASEBASE1_HISTYPE  CASEBASE1_HISTORY  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      1.0                1.0
# 0801110002 C0180073                      1.0                1.0
# 0801110003 C94C015B                      1.0                1.0
# 0801110004 C95B0268                      1.0                1.0
# 0801110005 C9840316                      0.0                0.0
#
#                            CASEBASE1_SALEITEM  CASEBASE1_CAPTIAL  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       2.0                9.0
# 0801110002 C0180073                       1.0                9.0
# 0801110003 C94C015B                       2.0               10.0
# 0801110004 C95B0268                       1.0                8.0
# 0801110005 C9840316                       1.0               12.0
#
#                            CASEBASE1_STOCKER  CASEBASE1_STOCKH  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      0.0              10.0
# 0801110002 C0180073                      0.0              10.0
# 0801110003 C94C015B                      0.0               9.0
# 0801110004 C95B0268                      0.0              13.0
# 0801110005 C9840316                      0.0              10.0
#
#                            CASEBASE1_OPERATE  CASEBASE1_MPLANT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      1.0               1.0
# 0801110002 C0180073                      2.0               1.0
# 0801110003 C94C015B                      2.0               1.0
# 0801110004 C95B0268                      1.0               2.0
# 0801110005 C9840316                      1.0               1.0
#
#                            CASEBASE1_PROCPLANT  CASEBASE1_PAWN  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        0.0             1.0
# 0801110002 C0180073                        3.0             0.0
# 0801110003 C94C015B                        1.0             0.0
# 0801110004 C95B0268                        6.0             1.0
# 0801110005 C9840316                       10.0             1.0
#
#                            CASEBASE1_RATEY1  CASEBASE1_RATEY2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   100.0             100.0
# 0801110002 C0180073                   100.0             100.0
# 0801110003 C94C015B                   100.0             100.0
# 0801110004 C95B0268                   100.0             100.0
# 0801110005 C9840316                   100.0             100.0
#
#                            CASEBASE1_RATEY3  CASEBASE1_GPY1  CASEBASE1_GPY2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   100.0           14.86           11.30
# 0801110002 C0180073                   100.0          -32.18          -78.71
# 0801110003 C94C015B                   100.0           -1.08            5.34
# 0801110004 C95B0268                   100.0           45.38            7.08
# 0801110005 C9840316                   100.0           -8.59          -18.90
#
#                            CASEBASE1_OPENYEAR  CASEBASE1_SALESTAT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       2.0                 3.0
# 0801110002 C0180073                       2.0                 3.0
# 0801110003 C94C015B                       3.0                 1.0
# 0801110004 C95B0268                       2.0                 4.0
# 0801110005 C9840316                       2.0                 3.0
#
#                            CASEBASE1_STUFFIN  CASEBASE1_STLC  CASEBASE1_STTT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      7.0             0.0             0.0
# 0801110002 C0180073                      1.0           100.0             0.0
# 0801110003 C94C015B                     11.0            10.0            90.0
# 0801110004 C95B0268                      6.0             0.0           100.0
# 0801110005 C9840316                      8.0            50.0            50.0
#
#                            CASEBASE1_STOTHER  CASEBASE1_STUFFOUT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    100.0                 1.0
# 0801110002 C0180073                      0.0                 2.0
# 0801110003 C94C015B                      0.0                 2.0
# 0801110004 C95B0268                      0.0                 2.0
# 0801110005 C9840316                      0.0                 1.0
#
#                           CASEBASE1_CORGTYPE  CASEBASE1_ONEEXPLAIN  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     股票上櫃                   1.0
# 0801110002 C0180073                     興櫃股票                   0.0
# 0801110003 C94C015B                     股票上櫃                   1.0
# 0801110004 C95B0268                     興櫃股票                   0.0
# 0801110005 C9840316                     股票上市                   0.0
#
#                            CASEBASE1_OPEOFFER_SEX  CASEBASE2_STUFFIN2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                           0.0                 0.0
# 0801110002 C0180073                           0.0                 2.0
# 0801110003 C94C015B                           0.0                 6.0
# 0801110004 C95B0268                           0.0                 5.0
# 0801110005 C9840316                           0.0                10.0
#
#                            CASEBASE2_PSLC  CASEBASE2_PSTT  CASEBASE2_PSOTHER  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   0.0             0.0              100.0
# 0801110002 C0180073                 100.0             0.0                0.0
# 0801110003 C94C015B                   0.0           100.0                0.0
# 0801110004 C95B0268                   0.0           100.0                0.0
# 0801110005 C9840316                  50.0            50.0                0.0
#
#                            CASEBASE2_STUFFOUT2  CASEBASE2_BANK  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        1.0             0.0
# 0801110002 C0180073                        2.0             2.0
# 0801110003 C94C015B                        1.0             1.0
# 0801110004 C95B0268                        4.0             2.0
# 0801110005 C9840316                        1.0             2.0
#
#                           CASEBASE2_BILL1 CASEBASE2_BILL2 CASEBASE2_BILL3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     N               Y               Y
# 0801110002 C0180073                     N               N               N
# 0801110003 C94C015B                     N               N               N
# 0801110004 C95B0268                     N               N               Y
# 0801110005 C9840316                     N               N               Y
#
#                            CASEBASE2_PRESBILL CASEBASE2_REFUND0  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       1.0                 Y
# 0801110002 C0180073                       0.0               NaN
# 0801110003 C94C015B                       0.0                 Y
# 0801110004 C95B0268                       0.0                 Y
# 0801110005 C9840316                       0.0                 Y
#
#                           CASEBASE2_REFUND1 CASEBASE2_REFUND2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       N                 N
# 0801110002 C0180073                     NaN               NaN
# 0801110003 C94C015B                       Y                 Y
# 0801110004 C95B0268                       N                 Y
# 0801110005 C9840316                       N                 Y
#
#                           CASEBASE2_REFUND3 CASEBASE2_REFUND4  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       N                 Y
# 0801110002 C0180073                     NaN                 Y
# 0801110003 C94C015B                       Y                 Y
# 0801110004 C95B0268                       Y                 Y
# 0801110005 C9840316                       Y                 Y
#
#                            CASEBASE2_LAWSUITREC  CASEBASE2_LAWSUIT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         0.0                0.0
# 0801110002 C0180073                         1.0                1.0
# 0801110003 C94C015B                         1.0                1.0
# 0801110004 C95B0268                         1.0                2.0
# 0801110005 C9840316                         1.0                2.0
#
#                            CASEBASE2_PATENT  CASEBASE2_PANTENTNO  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     0.0                  0.0
# 0801110002 C0180073                     1.0                  4.0
# 0801110003 C94C015B                     1.0                 13.0
# 0801110004 C95B0268                     0.0                  0.0
# 0801110005 C9840316                     1.0                  7.0
#
#                            CASEBASE2_PLACELIST  CASEBASE2_PLACENUM  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        0.0                 0.0
# 0801110002 C0180073                        0.0                 0.0
# 0801110003 C94C015B                        0.0                 0.0
# 0801110004 C95B0268                        0.0                 0.0
# 0801110005 C9840316                        0.0                 0.0
#
#                            CASEBASE2_EPLIST  CASEBASE2_INOUT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     5.0              2.0
# 0801110002 C0180073                     5.0              2.0
# 0801110003 C94C015B                     5.0              2.0
# 0801110004 C95B0268                     5.0              3.0
# 0801110005 C9840316                     5.0              3.0
#
#                            CASEBASE2_FINANCIAL  CASEBASE2_FINSTATE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        8.0                 0.0
# 0801110002 C0180073                        8.0                 0.0
# 0801110003 C94C015B                        8.0                 0.0
# 0801110004 C95B0268                        8.0                 0.0
# 0801110005 C9840316                        8.0                 0.0
#
#                           CASEBASE2_TAXTYPE CASEBASE2_CPATYPE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       N                 Y
# 0801110002 C0180073                       N                 Y
# 0801110003 C94C015B                       N                 Y
# 0801110004 C95B0268                       N                 Y
# 0801110005 C9840316                       N                 Y
#
#                           CASEBASE2_COMPTYPE  CASEBASE2_NEWS  CASEBASE2_BASIS  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        N             0.0              9.0
# 0801110002 C0180073                        N             0.0              9.0
# 0801110003 C94C015B                        N             4.0              9.0
# 0801110004 C95B0268                        N             2.0              9.0
# 0801110005 C9840316                        N             5.0              0.0
#
#                           CASEBASE2_PROPOSAL  CASEBASE2_RPTTYPE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        Z                2.0
# 0801110002 C0180073                        Z                2.0
# 0801110003 C94C015B                        Z                2.0
# 0801110004 C95B0268                        Z                2.0
# 0801110005 C9840316                        Z                2.0
#
#                           CASEBASE2_NOFINRPT CASEBASE2_MAXCREDIT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        N                   N
# 0801110002 C0180073                        N                   N
# 0801110003 C94C015B                        N                   N
# 0801110004 C95B0268                        N                   Y
# 0801110005 C9840316                        N                   Y
#
#                           CASEBASE2_PROCREDIT  CASEBASE2_NGETMSTOCK  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         N                   0.0
# 0801110002 C0180073                         N                   0.0
# 0801110003 C94C015B                         N                   0.0
# 0801110004 C95B0268                         N                   0.0
# 0801110005 C9840316                         N                   0.0
#
#                           CASEBASE3_FINCHK  CASEBASE3_NLIQUTRAN  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      Y                  0.0
# 0801110002 C0180073                      Y                  0.0
# 0801110003 C94C015B                      Y                  NaN
# 0801110004 C95B0268                      Y                  0.0
# 0801110005 C9840316                      Y                  0.0
#
#                            CASEBASE3_OPERTRAN  CASEBASE3_CHFOLW1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      0.55                0.0
# 0801110002 C0180073                      0.17                1.0
# 0801110003 C94C015B                      1.23                0.0
# 0801110004 C95B0268                      0.99                0.0
# 0801110005 C9840316                      0.74                1.0
#
#                            CASEBASE3_CHFOLW1AMT  CASEBASE3_CHFOLW2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     82671.0                0.0
# 0801110002 C0180073                     75385.0                0.0
# 0801110003 C94C015B                    204255.0                1.0
# 0801110004 C95B0268                     56590.0                1.0
# 0801110005 C9840316                     44714.0                1.0
#
#                            CASEBASE3_ANAYYEAR  CASEBASE3_LIQUVER  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    2006.0                1.0
# 0801110002 C0180073                    2006.0                1.0
# 0801110003 C94C015B                    2006.0                1.0
# 0801110004 C95B0268                    2006.0                1.0
# 0801110005 C9840316                    2006.0                1.0
#
#                            CASEBASE3_CASHVER  CASEFINANCIAL_1_FINDATE1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      1.0                  626578.0
# 0801110002 C0180073                      1.0                  295000.0
# 0801110003 C94C015B                      1.0                 1370000.0
# 0801110004 C95B0268                      1.0                  900000.0
# 0801110005 C9840316                      1.0                 1191258.0
#
#                            CASEFINANCIAL_8_FINDATE1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          2006.0
# 0801110002 C0180073                          2006.0
# 0801110003 C94C015B                          2006.0
# 0801110004 C95B0268                          2006.0
# 0801110005 C9840316                          2006.0
#
#                            CASEFINANCIAL_10_FINDATE1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          46187.0
# 0801110002 C0180073                          26730.0
# 0801110003 C94C015B                         251705.0
# 0801110004 C95B0268                         299666.0
# 0801110005 C9840316                          32474.0
#
#                            CASEFINANCIAL_11_FINDATE1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          20614.0
# 0801110002 C0180073                          33489.0
# 0801110003 C94C015B                         216010.0
# 0801110004 C95B0268                         131824.0
# 0801110005 C9840316                          56791.0
#
#                            CASEFINANCIAL_10_FINDATE2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          84964.0
# 0801110002 C0180073                          52588.0
# 0801110003 C94C015B                         412900.0
# 0801110004 C95B0268                          75907.0
# 0801110005 C9840316                          25230.0
#
#                            CASEFINANCIAL_11_FINDATE2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          75934.0
# 0801110002 C0180073                          56525.0
# 0801110003 C94C015B                         240074.0
# 0801110004 C95B0268                          25509.0
# 0801110005 C9840316                         251084.0
#
#                            CASEFINANCIAL_1_FINDATE3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        324104.0
# 0801110002 C0180073                        200000.0
# 0801110003 C94C015B                       1024000.0
# 0801110004 C95B0268                        565600.0
# 0801110005 C9840316                        903880.0
#
#                            CASEFINANCIAL_10_FINDATE3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          98327.0
# 0801110002 C0180073                          10477.0
# 0801110003 C94C015B                         400135.0
# 0801110004 C95B0268                         307793.0
# 0801110005 C9840316                         370590.0
#
#                            CASEFINANCIAL_11_FINDATE3  CASEINOUT_3_INOUT1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          77942.0                 1.0
# 0801110002 C0180073                           3678.0                 0.5
# 0801110003 C94C015B                         309748.0                 3.0
# 0801110004 C95B0268                         204303.0                 2.5
# 0801110005 C9840316                         268107.0                 8.5
#
#                            LAND_AREA_SUM  BUILD_AREA_SUM  CASEBASE5_TOPYEAR  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780              5773.00         6073.00             2008.0
# 0801110002 C0180073              2446.64         1898.54             2007.0
# 0801110003 C94C015B              1819.00        11240.00             2007.0
# 0801110004 C95B0268              7272.00         7901.00             2007.0
# 0801110005 C9840316              4001.00         7499.00             2007.0
#
#                           CASEBASE5_TOPBUSNAME CASEBASE5_ATTRIBUTE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    被動電子元件業                   M
# 0801110002 C0180073                        電池業                   M
# 0801110003 C94C015B                   其他電子零組件業                   M
# 0801110004 C95B0268                     印刷電路板業                   M
# 0801110005 C9840316                     印刷電路板業                   M
#
#                           CASEBASE5_ATTRIBNAME  CASEBASE5_TOPBUSSUMM  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        製造業                2746.0
# 0801110002 C0180073                        製造業                2709.0
# 0801110003 C94C015B                        製造業                2709.0
# 0801110004 C95B0268                        製造業                2709.0
# 0801110005 C9840316                        製造業                2709.0
#
#                            CASEBASE5_TOPBUSSUM  CASEBASE5_COMPBUSNO  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       63.0                 37.0
# 0801110002 C0180073                       17.0                  0.0
# 0801110003 C94C015B                      116.0                 19.0
# 0801110004 C95B0268                       75.0                 25.0
# 0801110005 C9840316                       75.0                 32.0
#
#                            CASEBASE5_TOPAVGEMP  CASEBASE5_TOPAVGSALE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      288.0             2041684.0
# 0801110002 C0180073                      295.0             3510459.0
# 0801110003 C94C015B                      470.0             5529818.0
# 0801110004 C95B0268                      793.0             4943723.0
# 0801110005 C9840316                      793.0             4943723.0
#
#                            CASEBASE5_TOPMINSORT  CASEBASE5_TOPMAXBUSSORT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      4921.0                    156.0
# 0801110002 C0180073                      4326.0                    116.0
# 0801110003 C94C015B                      4783.0                     12.0
# 0801110004 C95B0268                      4855.0                     41.0
# 0801110005 C9840316                      4855.0                     41.0
#
#                            CASEBASE5_TOPMINBUSSORT  CASEBASE5_TOPNOWBUSSORT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         2703.0                   1513.0
# 0801110002 C0180073                         2464.0                      0.0
# 0801110003 C94C015B                         2652.0                    468.0
# 0801110004 C95B0268                         2680.0                    623.0
# 0801110005 C9840316                         2680.0                    826.0
#
#                            CASEBASE5_TOPMAXEMP  CASEBASE5_TOPMINEMP  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     2586.0                 15.0
# 0801110002 C0180073                      905.0                 50.0
# 0801110003 C94C015B                    13322.0                 10.0
# 0801110004 C95B0268                     5985.0                 40.0
# 0801110005 C9840316                     5985.0                 40.0
#
#                            CASEBASE5_TOPMAXSALE  CASEBASE5_TOPMINSALE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  13165645.0              125298.0
# 0801110002 C0180073                  16310066.0              220540.0
# 0801110003 C94C015B                 181652407.0              129934.0
# 0801110004 C95B0268                  49801871.0              115900.0
# 0801110005 C9840316                  49801871.0              115900.0
#
#                            CASEBASE5_NOWSALEY  CASEBASE5_TOPMAXCAP  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    2006.0           24382213.0
# 0801110002 C0180073                    2006.0            2036188.0
# 0801110003 C94C015B                    2006.0           76235909.0
# 0801110004 C95B0268                    2006.0           12071291.0
# 0801110005 C9840316                    2006.0           12071291.0
#
#                            CASEBASE5_TOPMINCAP  CASEBASE5_TOPNOWCAP  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    50000.0             756997.0
# 0801110002 C0180073                    54000.0             385000.0
# 0801110003 C94C015B                    20000.0            1504000.0
# 0801110004 C95B0268                    40660.0            1075290.0
# 0801110005 C9840316                    40660.0            1193121.0
#
#                            CASEBASE5_FINACETYPE CASEBASE5_FINANCEBUSNAME  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         1.0                 其他電子零組件業
# 0801110002 C0180073                         1.0                      電池業
# 0801110003 C94C015B                         1.0                 其他電子零組件業
# 0801110004 C95B0268                         1.0                   印刷電路板業
# 0801110005 C9840316                         1.0                   印刷電路板業
#
#                            CASEBASE5_MED02  CASEBASE5_MED06  CASEBASE5_MED09  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  12.39            35.57           535.19
# 0801110002 C0180073                  17.99            41.06           400.88
# 0801110003 C94C015B                  14.64            39.11           475.16
# 0801110004 C95B0268                  25.62            42.15           258.91
# 0801110005 C9840316                  25.62            42.15           258.91
#
#                            CASEBASE5_MED10  CASEBASE5_MED23  CASEBASE5_MED24  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  55.14             6.48            10.61
# 0801110002 C0180073                   0.00             5.34            11.99
# 0801110003 C94C015B                   0.00             6.00             9.80
# 0801110004 C95B0268                   0.00             7.21            11.46
# 0801110005 C9840316                   0.00             7.21            11.46
#
#                            CASEBASE5_MED25  CASEBASE5_MED26  CASEBASE5_MED41  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   6.72            18.54             9.32
# 0801110002 C0180073                   6.03            37.86             6.10
# 0801110003 C94C015B                   6.30            18.54             7.80
# 0801110004 C95B0268                   7.51            20.97             9.05
# 0801110005 C9840316                   7.51            20.97             9.05
#
#                            CASEBASE5_MED42  CASEBASE5_MED43  CASEBASE5_MED45  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   3.42             6.21             0.86
# 0801110002 C0180073                   4.55             5.87             0.83
# 0801110003 C94C015B                   3.52             5.34             0.81
# 0801110004 C95B0268                   3.11             2.96             0.80
# 0801110005 C9840316                   3.11             2.96             0.80
#
#                            CASEBASE5_MED50  CASEBASE5_MED51  CASEBASE5_MED61  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   5.36             68.0           186.26
# 0801110002 C0180073                   6.36             58.0           179.61
# 0801110003 C94C015B                   5.09             72.0           165.80
# 0801110004 C95B0268                   4.90             75.0           145.34
# 0801110005 C9840316                   4.90             75.0           145.34
#
#                            CASEBASE5_MED62  CASEBASE5_MED64  CASEBASE5_MED65  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                 146.38            37.22           108.44
# 0801110002 C0180073                 123.03            60.55            81.42
# 0801110003 C94C015B                 137.10            45.57           105.28
# 0801110004 C95B0268                 116.54            40.01           119.25
# 0801110005 C9840316                 116.54            40.01           119.25
#
#                            CASEBASE5_MED67  CASEBASE5_MED71  CASEBASE5_MED72  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  14.02            12.77             4.94
# 0801110002 C0180073                  15.60             5.49             0.13
# 0801110003 C94C015B                  14.04            19.67             7.22
# 0801110004 C95B0268                  15.97            21.92             6.55
# 0801110005 C9840316                  15.97            21.92             6.55
#
#                            CASEBASE5_MED22  CASEBASE5_MED21  CASEBASE5_MED44  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    0.0              0.0              0.0
# 0801110002 C0180073                    0.0              0.0              0.0
# 0801110003 C94C015B                    0.0              0.0              0.0
# 0801110004 C95B0268                    0.0              0.0              0.0
# 0801110005 C9840316                    0.0              0.0              0.0
#
#                            CASEBASE5_REC_NO  CASEBASE5_MEMPLID  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   160.0              546.0
# 0801110002 C0180073                    10.0              982.0
# 0801110003 C94C015B                   146.0              546.0
# 0801110004 C95B0268                    60.0              982.0
# 0801110005 C9840316                    60.0              982.0
#
#                            CASEBASE5_TOPAVGCAP  CASEBASE5_TOPNOWASST  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  1236431.0             1811326.0
# 0801110002 C0180073                   801170.0              196029.0
# 0801110003 C94C015B                  1955412.0             3143217.0
# 0801110004 C95B0268                  1608159.0             2879075.0
# 0801110005 C9840316                  1608159.0             2526886.0
#
#                            CASEBASE5_TOPNOWNETWRT  CASEBASE5_TOPMAXASST  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      852689.0            49603313.0
# 0801110002 C0180073                      125566.0             9136650.0
# 0801110003 C94C015B                     2021511.0           374446256.0
# 0801110004 C95B0268                     1199624.0            47779916.0
# 0801110005 C9840316                     1291005.0            47779916.0
#
#                            CASEBASE5_TOPMINASST  CASEBASE5_TOPAVGASST  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    109807.0             3206501.0
# 0801110002 C0180073                    331062.0             3928758.0
# 0801110003 C94C015B                     80547.0             8675988.0
# 0801110004 C95B0268                    169345.0             5492326.0
# 0801110005 C9840316                    169345.0             5492326.0
#
#                            CASEBASE5_TOPMAXNETWRT  CASEBASE5_TOPMINNETWRT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    31946432.0                 41045.0
# 0801110002 C0180073                     5603209.0                169327.0
# 0801110003 C94C015B                   247965702.0                  6482.0
# 0801110004 C95B0268                    40416702.0                 32815.0
# 0801110005 C9840316                    40416702.0                 32815.0
#
#                            CASEBASE5_TOPAVGNETWRT  Flag_has_emplnum  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     2167368.0                 1
# 0801110002 C0180073                     1904907.0                 1
# 0801110003 C94C015B                     5597523.0                 1
# 0801110004 C95B0268                     3418253.0                 1
# 0801110005 C9840316                     3418253.0                 1
#
#                            Y_OPERATE1  Y_OPERATE2  Flag_CEMPL  CASE_Y  CASE_M  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780          805638.0    701387.0           1       8       1
# 0801110002 C0180073           31993.0     47175.0           1       8       1
# 0801110003 C94C015B         3797860.0   3839219.0           2       8       1
# 0801110004 C95B0268         2736536.0   1882370.0           2       8       1
# 0801110005 C9840316         1908341.0   2087679.0           2       8       1
#
#                           CASEBASE_BUSTYPE_4
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     1299
# 0801110002 C0180073                     1404
# 0801110003 C94C015B                     1299
# 0801110004 C95B0268                     1212
# 0801110005 C9840316                     1212

# %%
Data2.to_hdf('Data/Data_final.h5',key='w_opy2',format = 't')
#col_mapping.to_hdf('Outputfolder/Data.h5',key='mapping')

# %% [markdown]
# # 特徵選取

# %%
Data_final = Data2.dropna(axis = 0, how='any')
#Data_final = Data2

Data_final.head()
Data_final.shape
# Out:
#                            CASEBASE_EMPLNUM  CASEBASE_BUILDATE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     101               24.0
# 0801110004 C95B0268                     759               30.0
# 0801110005 C9840316                     632               23.0
# 0801110006 C94C005F                     846               33.0
# 0801110007 C9860065                    2500               34.0
#
#                           CASEBASE_CCOMPTYPE CASEBASE_CBUSKIND CASEBASE_RANK  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     大型企業               製造業             B
# 0801110004 C95B0268                     大型企業               製造業             B
# 0801110005 C9840316                     大型企業               製造業             B
# 0801110006 C94C005F                     大型企業               製造業             B
# 0801110007 C9860065                    超大型企業               製造業            B+
#
#                            CASEBASE_LEGAL CASEBASE_CCOUNTYOE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   1.0                桃園縣
# 0801110004 C95B0268                   1.0                台北市
# 0801110005 C9840316                   1.0                高雄縣
# 0801110006 C94C005F                   1.0                桃園縣
# 0801110007 C9860065                   1.0                高雄市
#
#                            CASEBASE1_FACTORY  CASEBASE1_CONGLOME  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      2.0                 5.0
# 0801110004 C95B0268                      3.0                 6.0
# 0801110005 C9840316                      2.0                 8.0
# 0801110006 C94C005F                      2.0                 4.0
# 0801110007 C9860065                      3.0                 3.0
#
#                            CASEBASE1_HISTYPE  CASEBASE1_HISTORY  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      1.0                1.0
# 0801110004 C95B0268                      1.0                1.0
# 0801110005 C9840316                      0.0                0.0
# 0801110006 C94C005F                      0.0                0.0
# 0801110007 C9860065                      0.0                0.0
#
#                            CASEBASE1_SALEITEM  CASEBASE1_CAPTIAL  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       2.0                9.0
# 0801110004 C95B0268                       1.0                8.0
# 0801110005 C9840316                       1.0               12.0
# 0801110006 C94C005F                       1.0               11.0
# 0801110007 C9860065                       1.0                4.0
#
#                            CASEBASE1_STOCKER  CASEBASE1_STOCKH  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      0.0              10.0
# 0801110004 C95B0268                      0.0              13.0
# 0801110005 C9840316                      0.0              10.0
# 0801110006 C94C005F                      0.0              10.0
# 0801110007 C9860065                      0.0              11.0
#
#                            CASEBASE1_OPERATE  CASEBASE1_MPLANT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      1.0               1.0
# 0801110004 C95B0268                      1.0               2.0
# 0801110005 C9840316                      1.0               1.0
# 0801110006 C94C005F                      2.0               2.0
# 0801110007 C9860065                      2.0               2.0
#
#                            CASEBASE1_PROCPLANT  CASEBASE1_PAWN  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        0.0             1.0
# 0801110004 C95B0268                        6.0             1.0
# 0801110005 C9840316                       10.0             1.0
# 0801110006 C94C005F                        8.0             1.0
# 0801110007 C9860065                        7.0             0.0
#
#                            CASEBASE1_RATEY1  CASEBASE1_RATEY2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   100.0             100.0
# 0801110004 C95B0268                   100.0             100.0
# 0801110005 C9840316                   100.0             100.0
# 0801110006 C94C005F                   100.0             100.0
# 0801110007 C9860065                   100.0             100.0
#
#                            CASEBASE1_RATEY3  CASEBASE1_GPY1  CASEBASE1_GPY2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   100.0           14.86           11.30
# 0801110004 C95B0268                   100.0           45.38            7.08
# 0801110005 C9840316                   100.0           -8.59          -18.90
# 0801110006 C94C005F                   100.0           51.90           19.53
# 0801110007 C9860065                   100.0           -3.21           -5.60
#
#                            CASEBASE1_OPENYEAR  CASEBASE1_SALESTAT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       2.0                 3.0
# 0801110004 C95B0268                       2.0                 4.0
# 0801110005 C9840316                       2.0                 3.0
# 0801110006 C94C005F                       2.0                 4.0
# 0801110007 C9860065                       3.0                 1.0
#
#                            CASEBASE1_STUFFIN  CASEBASE1_STLC  CASEBASE1_STTT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      7.0             0.0             0.0
# 0801110004 C95B0268                      6.0             0.0           100.0
# 0801110005 C9840316                      8.0            50.0            50.0
# 0801110006 C94C005F                      9.0           100.0             0.0
# 0801110007 C9860065                      5.0             0.0           100.0
#
#                            CASEBASE1_STOTHER  CASEBASE1_STUFFOUT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    100.0                 1.0
# 0801110004 C95B0268                      0.0                 2.0
# 0801110005 C9840316                      0.0                 1.0
# 0801110006 C94C005F                      0.0                 1.0
# 0801110007 C9860065                      0.0                 1.0
#
#                           CASEBASE1_CORGTYPE  CASEBASE1_ONEEXPLAIN  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     股票上櫃                   1.0
# 0801110004 C95B0268                     興櫃股票                   0.0
# 0801110005 C9840316                     股票上市                   0.0
# 0801110006 C94C005F                     股票上櫃                   1.0
# 0801110007 C9860065                     外資企業                   1.0
#
#                            CASEBASE1_OPEOFFER_SEX  CASEBASE2_STUFFIN2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                           0.0                 0.0
# 0801110004 C95B0268                           0.0                 5.0
# 0801110005 C9840316                           0.0                10.0
# 0801110006 C94C005F                           0.0                 9.0
# 0801110007 C9860065                           0.0                 8.0
#
#                            CASEBASE2_PSLC  CASEBASE2_PSTT  CASEBASE2_PSOTHER  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   0.0             0.0              100.0
# 0801110004 C95B0268                   0.0           100.0                0.0
# 0801110005 C9840316                  50.0            50.0                0.0
# 0801110006 C94C005F                 100.0             0.0                0.0
# 0801110007 C9860065                   0.0           100.0                0.0
#
#                            CASEBASE2_STUFFOUT2  CASEBASE2_BANK  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        1.0             0.0
# 0801110004 C95B0268                        4.0             2.0
# 0801110005 C9840316                        1.0             2.0
# 0801110006 C94C005F                        3.0             2.0
# 0801110007 C9860065                        2.0             2.0
#
#                           CASEBASE2_BILL1 CASEBASE2_BILL2 CASEBASE2_BILL3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     N               Y               Y
# 0801110004 C95B0268                     N               N               Y
# 0801110005 C9840316                     N               N               Y
# 0801110006 C94C005F                     N               N               N
# 0801110007 C9860065                     N               N               N
#
#                            CASEBASE2_PRESBILL CASEBASE2_REFUND0  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       1.0                 Y
# 0801110004 C95B0268                       0.0                 Y
# 0801110005 C9840316                       0.0                 Y
# 0801110006 C94C005F                       0.0                 Y
# 0801110007 C9860065                       0.0                 Y
#
#                           CASEBASE2_REFUND1 CASEBASE2_REFUND2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       N                 N
# 0801110004 C95B0268                       N                 Y
# 0801110005 C9840316                       N                 Y
# 0801110006 C94C005F                       N                 N
# 0801110007 C9860065                       N                 N
#
#                           CASEBASE2_REFUND3 CASEBASE2_REFUND4  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       N                 Y
# 0801110004 C95B0268                       Y                 Y
# 0801110005 C9840316                       Y                 Y
# 0801110006 C94C005F                       N                 Y
# 0801110007 C9860065                       N                 Y
#
#                            CASEBASE2_LAWSUITREC  CASEBASE2_LAWSUIT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         0.0                0.0
# 0801110004 C95B0268                         1.0                2.0
# 0801110005 C9840316                         1.0                2.0
# 0801110006 C94C005F                         1.0                4.0
# 0801110007 C9860065                         0.0                0.0
#
#                            CASEBASE2_PATENT  CASEBASE2_PANTENTNO  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     0.0                  0.0
# 0801110004 C95B0268                     0.0                  0.0
# 0801110005 C9840316                     1.0                  7.0
# 0801110006 C94C005F                     0.0                  0.0
# 0801110007 C9860065                     1.0                  4.0
#
#                            CASEBASE2_PLACELIST  CASEBASE2_PLACENUM  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        0.0                 0.0
# 0801110004 C95B0268                        0.0                 0.0
# 0801110005 C9840316                        0.0                 0.0
# 0801110006 C94C005F                        0.0                 0.0
# 0801110007 C9860065                        0.0                 0.0
#
#                            CASEBASE2_EPLIST  CASEBASE2_INOUT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     5.0              2.0
# 0801110004 C95B0268                     5.0              3.0
# 0801110005 C9840316                     5.0              3.0
# 0801110006 C94C005F                     5.0              3.0
# 0801110007 C9860065                     5.0              3.0
#
#                            CASEBASE2_FINANCIAL  CASEBASE2_FINSTATE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        8.0                 0.0
# 0801110004 C95B0268                        8.0                 0.0
# 0801110005 C9840316                        8.0                 0.0
# 0801110006 C94C005F                        8.0                 0.0
# 0801110007 C9860065                        8.0                 1.0
#
#                           CASEBASE2_TAXTYPE CASEBASE2_CPATYPE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       N                 Y
# 0801110004 C95B0268                       N                 Y
# 0801110005 C9840316                       N                 Y
# 0801110006 C94C005F                       N                 Y
# 0801110007 C9860065                       N                 N
#
#                           CASEBASE2_COMPTYPE  CASEBASE2_NEWS  CASEBASE2_BASIS  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        N             0.0              9.0
# 0801110004 C95B0268                        N             2.0              9.0
# 0801110005 C9840316                        N             5.0              0.0
# 0801110006 C94C005F                        N             6.0              0.0
# 0801110007 C9860065                        N             0.0              9.0
#
#                           CASEBASE2_PROPOSAL  CASEBASE2_RPTTYPE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        Z                2.0
# 0801110004 C95B0268                        Z                2.0
# 0801110005 C9840316                        Z                2.0
# 0801110006 C94C005F                        Z                2.0
# 0801110007 C9860065                        Z                2.0
#
#                           CASEBASE2_NOFINRPT CASEBASE2_MAXCREDIT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        N                   N
# 0801110004 C95B0268                        N                   Y
# 0801110005 C9840316                        N                   Y
# 0801110006 C94C005F                        N                   Y
# 0801110007 C9860065                        Y                   N
#
#                           CASEBASE2_PROCREDIT  CASEBASE2_NGETMSTOCK  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         N                   0.0
# 0801110004 C95B0268                         N                   0.0
# 0801110005 C9840316                         N                   0.0
# 0801110006 C94C005F                         N                   0.0
# 0801110007 C9860065                         Y                   0.0
#
#                           CASEBASE3_FINCHK  CASEBASE3_NLIQUTRAN  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      Y                 0.00
# 0801110004 C95B0268                      Y                 0.00
# 0801110005 C9840316                      Y                 0.00
# 0801110006 C94C005F                      Y                 0.00
# 0801110007 C9860065                      N                 1.56
#
#                            CASEBASE3_OPERTRAN  CASEBASE3_CHFOLW1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      0.55                0.0
# 0801110004 C95B0268                      0.99                0.0
# 0801110005 C9840316                      0.74                1.0
# 0801110006 C94C005F                      1.05                0.0
# 0801110007 C9860065                      0.00                0.0
#
#                            CASEBASE3_CHFOLW1AMT  CASEBASE3_CHFOLW2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     82671.0                0.0
# 0801110004 C95B0268                     56590.0                1.0
# 0801110005 C9840316                     44714.0                1.0
# 0801110006 C94C005F                     83284.0                1.0
# 0801110007 C9860065                         0.0                0.0
#
#                            CASEBASE3_ANAYYEAR  CASEBASE3_LIQUVER  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    2006.0                1.0
# 0801110004 C95B0268                    2006.0                1.0
# 0801110005 C9840316                    2006.0                1.0
# 0801110006 C94C005F                    2006.0                1.0
# 0801110007 C9860065                    2006.0                0.0
#
#                            CASEBASE3_CASHVER  CASEFINANCIAL_1_FINDATE1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      1.0                  626578.0
# 0801110004 C95B0268                      1.0                  900000.0
# 0801110005 C9840316                      1.0                 1191258.0
# 0801110006 C94C005F                      1.0                 1213147.0
# 0801110007 C9860065                      0.0                  366812.0
#
#                            CASEFINANCIAL_8_FINDATE1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          2006.0
# 0801110004 C95B0268                          2006.0
# 0801110005 C9840316                          2006.0
# 0801110006 C94C005F                          2006.0
# 0801110007 C9860065                          2006.0
#
#                            CASEFINANCIAL_10_FINDATE1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          46187.0
# 0801110004 C95B0268                         299666.0
# 0801110005 C9840316                          32474.0
# 0801110006 C94C005F                         281528.0
# 0801110007 C9860065                        1263624.0
#
#                            CASEFINANCIAL_11_FINDATE1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          20614.0
# 0801110004 C95B0268                         131824.0
# 0801110005 C9840316                          56791.0
# 0801110006 C94C005F                         139539.0
# 0801110007 C9860065                         903177.0
#
#                            CASEFINANCIAL_10_FINDATE2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          84964.0
# 0801110004 C95B0268                          75907.0
# 0801110005 C9840316                          25230.0
# 0801110006 C94C005F                         105173.0
# 0801110007 C9860065                              0.0
#
#                            CASEFINANCIAL_11_FINDATE2  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          75934.0
# 0801110004 C95B0268                          25509.0
# 0801110005 C9840316                         251084.0
# 0801110006 C94C005F                          31709.0
# 0801110007 C9860065                              0.0
#
#                            CASEFINANCIAL_1_FINDATE3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        324104.0
# 0801110004 C95B0268                        565600.0
# 0801110005 C9840316                        903880.0
# 0801110006 C94C005F                        913147.0
# 0801110007 C9860065                             0.0
#
#                            CASEFINANCIAL_10_FINDATE3  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          98327.0
# 0801110004 C95B0268                         307793.0
# 0801110005 C9840316                         370590.0
# 0801110006 C94C005F                         177123.0
# 0801110007 C9860065                              0.0
#
#                            CASEFINANCIAL_11_FINDATE3  CASEINOUT_3_INOUT1  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                          77942.0                1.00
# 0801110004 C95B0268                         204303.0                2.50
# 0801110005 C9840316                         268107.0                8.50
# 0801110006 C94C005F                         270361.0                1.15
# 0801110007 C9860065                              0.0              133.22
#
#                            LAND_AREA_SUM  BUILD_AREA_SUM  CASEBASE5_TOPYEAR  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780               5773.0         6073.00             2008.0
# 0801110004 C95B0268               7272.0         7901.00             2007.0
# 0801110005 C9840316               4001.0         7499.00             2007.0
# 0801110006 C94C005F              17821.0        21701.05             2007.0
# 0801110007 C9860065              40400.0        14400.00             2007.0
#
#                           CASEBASE5_TOPBUSNAME CASEBASE5_ATTRIBUTE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    被動電子元件業                   M
# 0801110004 C95B0268                     印刷電路板業                   M
# 0801110005 C9840316                     印刷電路板業                   M
# 0801110006 C94C005F                     印刷電路板業                   M
# 0801110007 C9860065                     印刷電路板業                   M
#
#                           CASEBASE5_ATTRIBNAME  CASEBASE5_TOPBUSSUMM  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                        製造業                2746.0
# 0801110004 C95B0268                        製造業                2709.0
# 0801110005 C9840316                        製造業                2709.0
# 0801110006 C94C005F                        製造業                2709.0
# 0801110007 C9860065                        製造業                2709.0
#
#                            CASEBASE5_TOPBUSSUM  CASEBASE5_COMPBUSNO  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                       63.0                 37.0
# 0801110004 C95B0268                       75.0                 25.0
# 0801110005 C9840316                       75.0                 32.0
# 0801110006 C94C005F                       75.0                 23.0
# 0801110007 C9860065                       75.0                  9.0
#
#                            CASEBASE5_TOPAVGEMP  CASEBASE5_TOPAVGSALE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      288.0             2041684.0
# 0801110004 C95B0268                      793.0             4943723.0
# 0801110005 C9840316                      793.0             4943723.0
# 0801110006 C94C005F                      793.0             4943723.0
# 0801110007 C9860065                      793.0             4943723.0
#
#                            CASEBASE5_TOPMINSORT  CASEBASE5_TOPMAXBUSSORT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      4921.0                    156.0
# 0801110004 C95B0268                      4855.0                     41.0
# 0801110005 C9840316                      4855.0                     41.0
# 0801110006 C94C005F                      4855.0                     41.0
# 0801110007 C9860065                      4855.0                     41.0
#
#                            CASEBASE5_TOPMINBUSSORT  CASEBASE5_TOPNOWBUSSORT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         2703.0                   1513.0
# 0801110004 C95B0268                         2680.0                    623.0
# 0801110005 C9840316                         2680.0                    826.0
# 0801110006 C94C005F                         2680.0                    576.0
# 0801110007 C9860065                         2680.0                    190.0
#
#                            CASEBASE5_TOPMAXEMP  CASEBASE5_TOPMINEMP  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     2586.0                 15.0
# 0801110004 C95B0268                     5985.0                 40.0
# 0801110005 C9840316                     5985.0                 40.0
# 0801110006 C94C005F                     5985.0                 40.0
# 0801110007 C9860065                     5985.0                 40.0
#
#                            CASEBASE5_TOPMAXSALE  CASEBASE5_TOPMINSALE  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  13165645.0              125298.0
# 0801110004 C95B0268                  49801871.0              115900.0
# 0801110005 C9840316                  49801871.0              115900.0
# 0801110006 C94C005F                  49801871.0              115900.0
# 0801110007 C9860065                  49801871.0              115900.0
#
#                            CASEBASE5_NOWSALEY  CASEBASE5_TOPMAXCAP  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    2006.0           24382213.0
# 0801110004 C95B0268                    2006.0           12071291.0
# 0801110005 C9840316                    2006.0           12071291.0
# 0801110006 C94C005F                    2006.0           12071291.0
# 0801110007 C9860065                    2006.0           12071291.0
#
#                            CASEBASE5_TOPMINCAP  CASEBASE5_TOPNOWCAP  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    50000.0             756997.0
# 0801110004 C95B0268                    40660.0            1075290.0
# 0801110005 C9840316                    40660.0            1193121.0
# 0801110006 C94C005F                    40660.0            1213147.0
# 0801110007 C9860065                    40660.0             366812.0
#
#                            CASEBASE5_FINACETYPE CASEBASE5_FINANCEBUSNAME  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                         1.0                 其他電子零組件業
# 0801110004 C95B0268                         1.0                   印刷電路板業
# 0801110005 C9840316                         1.0                   印刷電路板業
# 0801110006 C94C005F                         1.0                   印刷電路板業
# 0801110007 C9860065                         1.0                   印刷電路板業
#
#                            CASEBASE5_MED02  CASEBASE5_MED06  CASEBASE5_MED09  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  12.39            35.57           535.19
# 0801110004 C95B0268                  25.62            42.15           258.91
# 0801110005 C9840316                  25.62            42.15           258.91
# 0801110006 C94C005F                  25.62            42.15           258.91
# 0801110007 C9860065                  25.62            42.15           258.91
#
#                            CASEBASE5_MED10  CASEBASE5_MED23  CASEBASE5_MED24  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  55.14             6.48            10.61
# 0801110004 C95B0268                   0.00             7.21            11.46
# 0801110005 C9840316                   0.00             7.21            11.46
# 0801110006 C94C005F                   0.00             7.21            11.46
# 0801110007 C9860065                   0.00             7.21            11.46
#
#                            CASEBASE5_MED25  CASEBASE5_MED26  CASEBASE5_MED41  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   6.72            18.54             9.32
# 0801110004 C95B0268                   7.51            20.97             9.05
# 0801110005 C9840316                   7.51            20.97             9.05
# 0801110006 C94C005F                   7.51            20.97             9.05
# 0801110007 C9860065                   7.51            20.97             9.05
#
#                            CASEBASE5_MED42  CASEBASE5_MED43  CASEBASE5_MED45  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   3.42             6.21             0.86
# 0801110004 C95B0268                   3.11             2.96             0.80
# 0801110005 C9840316                   3.11             2.96             0.80
# 0801110006 C94C005F                   3.11             2.96             0.80
# 0801110007 C9860065                   3.11             2.96             0.80
#
#                            CASEBASE5_MED50  CASEBASE5_MED51  CASEBASE5_MED61  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   5.36             68.0           186.26
# 0801110004 C95B0268                   4.90             75.0           145.34
# 0801110005 C9840316                   4.90             75.0           145.34
# 0801110006 C94C005F                   4.90             75.0           145.34
# 0801110007 C9860065                   4.90             75.0           145.34
#
#                            CASEBASE5_MED62  CASEBASE5_MED64  CASEBASE5_MED65  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                 146.38            37.22           108.44
# 0801110004 C95B0268                 116.54            40.01           119.25
# 0801110005 C9840316                 116.54            40.01           119.25
# 0801110006 C94C005F                 116.54            40.01           119.25
# 0801110007 C9860065                 116.54            40.01           119.25
#
#                            CASEBASE5_MED67  CASEBASE5_MED71  CASEBASE5_MED72  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  14.02            12.77             4.94
# 0801110004 C95B0268                  15.97            21.92             6.55
# 0801110005 C9840316                  15.97            21.92             6.55
# 0801110006 C94C005F                  15.97            21.92             6.55
# 0801110007 C9860065                  15.97            21.92             6.55
#
#                            CASEBASE5_MED22  CASEBASE5_MED21  CASEBASE5_MED44  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    0.0              0.0              0.0
# 0801110004 C95B0268                    0.0              0.0              0.0
# 0801110005 C9840316                    0.0              0.0              0.0
# 0801110006 C94C005F                    0.0              0.0              0.0
# 0801110007 C9860065                    0.0              0.0              0.0
#
#                            CASEBASE5_REC_NO  CASEBASE5_MEMPLID  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                   160.0              546.0
# 0801110004 C95B0268                    60.0              982.0
# 0801110005 C9840316                    60.0              982.0
# 0801110006 C94C005F                    60.0              546.0
# 0801110007 C9860065                    60.0              546.0
#
#                            CASEBASE5_TOPAVGCAP  CASEBASE5_TOPNOWASST  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                  1236431.0             1811326.0
# 0801110004 C95B0268                  1608159.0             2879075.0
# 0801110005 C9840316                  1608159.0             2526886.0
# 0801110006 C94C005F                  1608159.0             3549943.0
# 0801110007 C9860065                  1608159.0             9468040.0
#
#                            CASEBASE5_TOPNOWNETWRT  CASEBASE5_TOPMAXASST  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                      852689.0            49603313.0
# 0801110004 C95B0268                     1199624.0            47779916.0
# 0801110005 C9840316                     1291005.0            47779916.0
# 0801110006 C94C005F                     1330989.0            47779916.0
# 0801110007 C9860065                     6612090.0            47779916.0
#
#                            CASEBASE5_TOPMINASST  CASEBASE5_TOPAVGASST  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    109807.0             3206501.0
# 0801110004 C95B0268                    169345.0             5492326.0
# 0801110005 C9840316                    169345.0             5492326.0
# 0801110006 C94C005F                    169345.0             5492326.0
# 0801110007 C9860065                    169345.0             5492326.0
#
#                            CASEBASE5_TOPMAXNETWRT  CASEBASE5_TOPMINNETWRT  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                    31946432.0                 41045.0
# 0801110004 C95B0268                    40416702.0                 32815.0
# 0801110005 C9840316                    40416702.0                 32815.0
# 0801110006 C94C005F                    40416702.0                 32815.0
# 0801110007 C9860065                    40416702.0                 32815.0
#
#                            CASEBASE5_TOPAVGNETWRT  Flag_has_emplnum  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     2167368.0                 1
# 0801110004 C95B0268                     3418253.0                 1
# 0801110005 C9840316                     3418253.0                 1
# 0801110006 C94C005F                     3418253.0                 1
# 0801110007 C9860065                     3418253.0                 1
#
#                            Y_OPERATE1  Y_OPERATE2  Flag_CEMPL  CASE_Y  CASE_M  \
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780          805638.0    701387.0           1       8       1
# 0801110004 C95B0268         2736536.0   1882370.0           2       8       1
# 0801110005 C9840316         1908341.0   2087679.0           2       8       1
# 0801110006 C94C005F         2995385.0   1971958.0           2       8       1
# 0801110007 C9860065        10000000.0  10331605.0           1       8       1
#
#                           CASEBASE_BUSTYPE_4
# CASE_ID    CASEBASE_CP_ID
# 0801110001 C0460780                     1299
# 0801110004 C95B0268                     1212
# 0801110005 C9840316                     1212
# 0801110006 C94C005F                     1212
# 0801110007 C9860065                     1212
# (67539, 156)

# %% [markdown]
# # Y_OPERATE1 極端值

# %%
Q1 =  Data_final['Y_OPERATE1'].quantile(0.25)
Q3 = Data_final['Y_OPERATE1'] .quantile(0.75)
IQR = Q3 - Q1
IQR

## 用 Q1 - 1.5 * IQR,  Q3 + 1.5*IQR
Y_no_outliar = Data_final['Y_OPERATE1'][~((Data_final['Y_OPERATE1'] < (Q1 - 1.5 * IQR)) |(Data_final['Y_OPERATE1'] > (Q3 + 1.5 * IQR)))]

Y_no_outliar.describe()
plt.hist(Y_no_outliar)

idx_iqr = Y_no_outliar.index
# Out:
# 3399393.5
# count    5.711700e+04
# mean     1.339834e+06
# std      1.805496e+06
# min     -9.000000e+00
# 25%      1.600000e+05
# 50%      5.500000e+05
# 75%      1.754308e+06
# max      8.693000e+06
# Name: Y_OPERATE1, dtype: float64
# (array([34175.,  8565.,  4641.,  2972.,  1932.,  1447.,  1015.,   894.,
#           830.,   646.]),
#  array([-9.0000000e+00,  8.6929190e+05,  1.7385928e+06,  2.6078937e+06,
#          3.4771946e+06,  4.3464955e+06,  5.2157964e+06,  6.0850973e+06,
#          6.9543982e+06,  7.8236991e+06,  8.6930000e+06]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # 納入模行資料筆數

# %%
Data_M = Data_final
Data_M.shape


y_M = Data_M[y_col[0]]
X_M = Data_M.drop(columns=y_col)
# Out:
# (67539, 156)

# %%
corr_matrix = Data_M.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
cols = corr_matrix[corr_matrix['Y_OPERATE1'].abs() > 0.6]['Y_OPERATE1'].index.to_list()
sns.pairplot(Data_M[cols], height=3.5)
plt.tight_layout()
plt.show()

# %%
import numpy as np
cm = np.corrcoef(Data_M[cols].values.T)
plt.figure(figsize = (16,10))
sns.set(font_scale=1.5)
hm = sns.heatmap(cm,
                 cbar=True,
                 annot=True,
                 square=True,
                 fmt='.2f',
                 annot_kws={'size': 15},
                 yticklabels=cols,
                 xticklabels=cols)
plt.show()

# %% [markdown]
# # BY 年度的案件數目

# %%
X_date_count = pd.DataFrame(X_M.groupby('20'+X_M.index.get_level_values('CASE_ID').str[0:2]).size())

# %%
plt.ion()

plt.plot(X_date_count,'-o');
plt.xticks(rotation=60);
plt.title('amount of CASE_ID in every years');
plt.xlabel('years');
plt.ylabel('amount');
plt.grid(axis='y');
## 均勻挑
## 不需要考慮時間

# %% [markdown]
# # 變數重要性

# %%
categorical_columns = list(set(X_M.columns.to_list()) & set(col_object))

numerical_columns =  list(set(X_M.columns.to_list()) & set(col_numeric))

# %%
## 將中文轉換為數值標記

from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
from sklearn.preprocessing import LabelEncoder

cat_mappoing = dict()

for i in categorical_columns:
    
    if is_numeric_dtype(X_M[i]):
        continue
    elif is_string_dtype(X_M[i]):
        if sum(X_M[i].str.isnumeric()) > 1:
            continue
        else:
            pass
    else:
        pass
        
    
    label = LabelEncoder()
    X_M.loc[:,i] = label.fit_transform(X_M.loc[:,i])
    le_name_mapping = dict(zip(label.classes_, label.transform(label.classes_)))
    cat_mappoing.update({i:le_name_mapping})

cat_mappoing
# Out:
# {'CASEBASE3_FINCHK': {'N': 0, 'Y': 1},
#  'CASEBASE2_REFUND1': {'N': 0, 'Y': 1},
#  'CASEBASE5_FINANCEBUSNAME': {'一般批發零售業': 0,
#   '一般投資業': 1,
#   '不動產業': 2,
#   '不動產經紀業': 3,
#   '乳品業': 4,
#   '事務機器業': 5,
#   '五金製品業': 6,
#   '人纖紡織業': 7,
#   '人纖製造業': 8,
#   '休閒服務業': 9,
#   '便利商店業': 10,
#   '保全服務業': 11,
#   '倉儲貨運業': 12,
#   '倉儲運輸業': 13,
#   '傳播媒體業': 14,
#   '光學及精密器械業': 15,
#   '光學器材業': 16,
#   '光電材料、元件及成品業': 17,
#   '光電材料及元件製造業': 18,
#   '其他化學材料及化學製品業': 19,
#   '其他專業技術服務業': 20,
#   '其他工業製品業': 21,
#   '其他服務業': 22,
#   '其他機械業': 23,
#   '其他紡織及製品業': 24,
#   '其他資訊服務業': 25,
#   '其他金屬基本工業': 26,
#   '其他金屬製品業': 27,
#   '其他電力器材業': 28,
#   '其他電子零組件業': 29,
#   '其他電腦設備業': 30,
#   '其他非金屬礦物製品業': 31,
#   '其他食品業': 32,
#   '冷凍食品業': 33,
#   '出版及行銷業': 34,
#   '出版業': 35,
#   '出版行銷業': 36,
#   '分期付款業': 37,
#   '加油站業': 38,
#   '化學品': 39,
#   '化學材料及製品業': 40,
#   '半導體業': 41,
#   '印刷業': 42,
#   '印刷電路板業': 43,
#   '合成樹脂及塑膠業': 44,
#   '合成橡膠業': 45,
#   '基本化學工業': 46,
#   '塑膠製品業': 47,
#   '塗料、染料及顏料業': 48,
#   '客運業': 49,
#   '家用電器業': 50,
#   '專業技術服務業': 51,
#   '專用生產機業': 52,
#   '工程技術服務業': 53,
#   '廣告業': 54,
#   '建築投資業': 55,
#   '成衣及服飾品業': 56,
#   '支援服務業': 57,
#   '旅館業': 58,
#   '有線通信機械器材業': 59,
#   '木竹藤製品業': 60,
#   '染整業': 61,
#   '棉紡織業': 62,
#   '機械設備業': 63,
#   '機車及其零件業': 64,
#   '橡、塑膠製品業': 65,
#   '橡膠製品業': 66,
#   '毛紡織業': 67,
#   '氣體燃料供應業': 68,
#   '水泥及其製品業': 69,
#   '汽車及其零件業': 70,
#   '汽車買賣業': 71,
#   '油墨業': 72,
#   '消費性電子產品業': 73,
#   '清潔用品及化妝品業': 74,
#   '清潔用品及化粧品業': 75,
#   '無店面零售業': 76,
#   '無線通信機械器材業': 77,
#   '照明設備業': 78,
#   '營造業': 79,
#   '玻璃及其製品業': 80,
#   '環境衛生及污染防治服務業': 81,
#   '生物技術服務業': 82,
#   '百貨公司業': 83,
#   '百貨批發零售業': 84,
#   '皮革、毛皮及其製品業': 85,
#   '直銷業': 86,
#   '石油化學製品業': 87,
#   '租賃及分期付款業': 88,
#   '租賃業': 89,
#   '積體電路設計業': 90,
#   '米麥粉及其製品業': 91,
#   '精密儀器製造業': 92,
#   '紙漿、紙及紙製品業': 93,
#   '紡織業': 94,
#   '維修服務業': 95,
#   '網路設備業': 96,
#   '網路資訊供應業': 97,
#   '罐頭食品及調味品業': 98,
#   '耐火材料業': 99,
#   '肥料業': 100,
#   '育樂用品業': 101,
#   '膠帶業': 102,
#   '自行車及其零件業': 103,
#   '航空器及其零件業': 104,
#   '航運業': 105,
#   '船舶及其零件業': 106,
#   '被動電子元件業': 107,
#   '製藥業': 108,
#   '視聽電子產品製造業': 109,
#   '資料儲存媒體製造及複製業': 110,
#   '資料處理服務業': 111,
#   '資訊服務業': 112,
#   '資訊電子及通信器材業': 113,
#   '農、林、漁、牧業': 114,
#   '農產品及食品業': 115,
#   '通用機械設備業': 116,
#   '通訊器材批售業': 117,
#   '進出口貿易業': 118,
#   '遊戲軟體業': 119,
#   '運輸工具及零件業': 120,
#   '運輸輔助業': 121,
#   '醫療保健及社會服務業': 122,
#   '醫療保健服務業': 123,
#   '醫療器材及設備業': 124,
#   '金屬加工機業': 125,
#   '金屬基本工業及其製品業': 126,
#   '金屬家具及裝設品業': 127,
#   '金融及輔助業': 128,
#   '銀行業': 129,
#   '銅基本工業及其製品業': 130,
#   '鋁基本工業及其製品業': 131,
#   '鋼鐵基本工業': 132,
#   '鋼鐵製品業': 133,
#   '鍋爐及原動機業': 134,
#   '陶瓷製品業': 135,
#   '零售式量販業': 136,
#   '電信業': 137,
#   '電力供應業': 138,
#   '電力機械器材業': 139,
#   '電力燃料供應業': 140,
#   '電子用化學材料業': 141,
#   '電子零組件批售業': 142,
#   '電影業': 143,
#   '電池業': 144,
#   '電線及電纜業': 145,
#   '電腦及其週邊設備、軟體批售業': 146,
#   '電腦系統整合服務業': 147,
#   '電腦終端裝置業': 148,
#   '電腦組件業': 149,
#   '電腦製造業': 150,
#   '電腦軟體服務業': 151,
#   '電腦週邊設備業': 152,
#   '非金屬礦物製品業': 153,
#   '鞋類業': 154,
#   '食用油脂業': 155,
#   '飲料業': 156,
#   '飼料配製業': 157,
#   '餐飲業': 158},
#  'CASEBASE2_BILL1': {'N': 0, 'S': 1, 'T': 2, 'Y': 3},
#  'CASEBASE_CCOMPTYPE': {'不詳': 0,
#   '中型企業': 1,
#   '中小型企業': 2,
#   '大型企業': 3,
#   '小型企業': 4,
#   '超大型企業': 5},
#  'CASEBASE_CBUSKIND': {'服務業': 0, '製造業': 1, '金融業': 2},
#  'CASEBASE2_REFUND0': {'N': 0, 'Y': 1},
#  'CASEBASE5_ATTRIBUTE': {'B': 0, 'G': 1, 'M': 2, 'N': 3},
#  'CASEBASE2_MAXCREDIT': {'N': 0, 'Y': 1},
#  'CASEBASE2_PROCREDIT': {'N': 0, 'Y': 1},
#  'CASEBASE2_REFUND2': {'N': 0, 'Y': 1},
#  'CASEBASE2_TAXTYPE': {'N': 0, 'Y': 1},
#  'CASEBASE5_ATTRIBNAME': {'公營事業': 0, '服務業': 1, '製造業': 2, '金融業': 3},
#  'CASEBASE2_CPATYPE': {'N': 0, 'Y': 1},
#  'CASEBASE2_COMPTYPE': {'N': 0, 'Y': 1},
#  'CASEBASE5_TOPBUSNAME': {'一般批發零售業': 0,
#   '一般投資業': 1,
#   '不動產服務業': 2,
#   '不動產業': 3,
#   '不動產經紀業': 4,
#   '乳品業': 5,
#   '事務機器業': 6,
#   '五金製品業': 7,
#   '人纖紡織業': 8,
#   '人纖製造業': 9,
#   '休閒服務業': 10,
#   '便利商店業': 11,
#   '保全服務業': 12,
#   '倉儲貨運業': 13,
#   '傳播媒體業': 14,
#   '光學器材業': 15,
#   '光電材料、元件及成品業': 16,
#   '光電材料及元件製造業': 17,
#   '公營事業': 18,
#   '其他光電材料及元件業': 19,
#   '其他化學材料及化學製品業': 20,
#   '其他專業技術服務業': 21,
#   '其他工業製品業': 22,
#   '其他服務業': 23,
#   '其他機械業': 24,
#   '其他紡織及製品業': 25,
#   '其他資訊服務業': 26,
#   '其他運輸工具及零件業': 27,
#   '其他金屬基本工業': 28,
#   '其他金屬製品業': 29,
#   '其他鋼鐵製品業': 30,
#   '其他電力器材業': 31,
#   '其他電子零組件業': 32,
#   '其他電腦設備業': 33,
#   '其他非金屬礦物製品業': 34,
#   '其他食品業': 35,
#   '冷凍食品業': 36,
#   '出版業': 37,
#   '出版行銷業': 38,
#   '加油站業': 39,
#   '化學品': 40,
#   '化學材料及製品業': 41,
#   '半導體業': 42,
#   '印刷業': 43,
#   '印刷電路板業': 44,
#   '合成樹脂及塑膠業': 45,
#   '合成橡膠業': 46,
#   '商品檢驗服務業': 47,
#   '基本化學工業': 48,
#   '塑膠製品業': 49,
#   '塗料、染料及顏料業': 50,
#   '太陽能電池': 51,
#   '客運業': 52,
#   '室內設計業': 53,
#   '家用電器業': 54,
#   '專業技術服務業': 55,
#   '專用生產機業': 56,
#   '工業用塑膠製品業': 57,
#   '工程技術服務業': 58,
#   '廢棄物處理與清除業': 59,
#   '廣告業': 60,
#   '建築及礦業機械設備業': 61,
#   '建築投資業': 62,
#   '成衣及服飾品業': 63,
#   '支援服務業': 64,
#   '旅館業': 65,
#   '有線通信機械器材業': 66,
#   '木竹藤製品業': 67,
#   '染整業': 68,
#   '棉紡織業': 69,
#   '機械設備業': 70,
#   '機車及其零件業': 71,
#   '橡、塑膠製品業': 72,
#   '橡膠製品業': 73,
#   '毛紡織業': 74,
#   '氣體燃料供應業': 75,
#   '水上運輸業': 76,
#   '水泥及其製品業': 77,
#   '污染防治設備業': 78,
#   '汽車及其零件業': 79,
#   '汽車貨運業': 80,
#   '汽車買賣業': 81,
#   '汽車零件製造業': 82,
#   '油墨業': 83,
#   '消費性電子產品業': 84,
#   '液晶面板及其組件製造業': 85,
#   '清潔用品及化妝品業': 86,
#   '清潔用品及化粧品業': 87,
#   '潤滑油業': 88,
#   '無店面零售業': 89,
#   '無線通信機械器材業': 90,
#   '照明設備業': 91,
#   '營造業': 92,
#   '玻璃及其製品業': 93,
#   '環境檢測服務業': 94,
#   '環境衛生及污染防治服務業': 95,
#   '瓦斯爐熱水器業': 96,
#   '生物技術服務業': 97,
#   '百貨公司業': 98,
#   '皮革、毛皮整製業': 99,
#   '皮革、毛皮製品業': 100,
#   '直銷業': 101,
#   '石材製品業': 102,
#   '石油化學製品業': 103,
#   '租賃及分期付款業': 104,
#   '積體電路設計業': 105,
#   '米麥粉及其製品業': 106,
#   '精密儀器製造業': 107,
#   '紙漿、紙及紙製品業': 108,
#   '維修服務業': 109,
#   '網路設備業': 110,
#   '網路資訊供應業': 111,
#   '罐頭食品及調味品業': 112,
#   '翻譯服務業': 113,
#   '耐火材料業': 114,
#   '肥料業': 115,
#   '育樂用品業': 116,
#   '膠帶業': 117,
#   '膠水及接合劑業': 118,
#   '自行車及其零件業': 119,
#   '航空器及其零件業': 120,
#   '航運業': 121,
#   '船舶及其零件業': 122,
#   '被動電子元件業': 123,
#   '製藥業': 124,
#   '視聽電子產品製造業': 125,
#   '設計業': 126,
#   '調整食品業': 127,
#   '調理食品業': 128,
#   '資料儲存媒體製造及複製業': 129,
#   '資料處理服務業': 130,
#   '資訊服務業': 131,
#   '資訊電子及通信器材業': 132,
#   '超級市場業': 133,
#   '軌道車輛及其零件業': 134,
#   '農、林、漁、牧業': 135,
#   '農業及園藝機械業': 136,
#   '農漁會信用部': 137,
#   '通用機械設備業': 138,
#   '通訊器材批售業': 139,
#   '進出口貿易業': 140,
#   '進口貿易業': 141,
#   '遊戲軟體業': 142,
#   '運輸工具及零件業': 143,
#   '運輸輔助業': 144,
#   '醫療保健及社會服務業': 145,
#   '醫療保健服務業': 146,
#   '醫療器材及設備業': 147,
#   '金屬加工機業': 148,
#   '金屬家具及裝設品業': 149,
#   '金屬線製品業': 150,
#   '銀行業': 151,
#   '銅基本工業及其製品業': 152,
#   '鋁基本工業及其製品業': 153,
#   '鋼鐵基本工業': 154,
#   '鋼鐵製品業': 155,
#   '鍋爐及原動機業': 156,
#   '鎂基本工業及其製品業': 157,
#   '鐘錶製造業': 158,
#   '陶瓷製品業': 159,
#   '零售式量販業': 160,
#   '電信業': 161,
#   '電力供應業': 162,
#   '電力機械器材業': 163,
#   '電力燃料供應業': 164,
#   '電子用化學材料業': 165,
#   '電子管業': 166,
#   '電子零組件批售業': 167,
#   '電影業': 168,
#   '電池業': 169,
#   '電線及電纜業': 170,
#   '電腦及其週邊設備、軟體批售業': 171,
#   '電腦系統整合服務業': 172,
#   '電腦終端裝置業': 173,
#   '電腦組件業': 174,
#   '電腦製造業': 175,
#   '電腦軟體服務業': 176,
#   '電腦週邊設備業': 177,
#   '非金屬礦物製品業': 178,
#   '鞋類業': 179,
#   '顧問服務業': 180,
#   '食用油脂業': 181,
#   '飲料業': 182,
#   '飼料配製業': 183,
#   '餐飲業': 184},
#  'CASEBASE1_CORGTYPE': {'公營企業': 0,
#   '公開發行': 1,
#   '創櫃股票': 2,
#   '合作社': 3,
#   '合夥': 4,
#   '外資企業': 5,
#   '外資合作': 6,
#   '家屬企業': 7,
#   '有大陸投資人': 8,
#   '獨資': 9,
#   '社團法人': 10,
#   '股票上市': 11,
#   '股票上櫃': 12,
#   '興櫃股票': 13,
#   '財團法人': 14,
#   '農企業機構': 15,
#   '農民團體': 16,
#   '醫療院所': 17,
#   '非家屬企業': 18},
#  'CASEBASE2_REFUND3': {'N': 0, 'Y': 1},
#  'CASEBASE2_BILL3': {'N': 0, 'Y': 1},
#  'CASEBASE2_REFUND4': {'N': 0, 'Y': 1},
#  'CASEBASE_CCOUNTYOE': {'南投縣': 0,
#   '台中市': 1,
#   '台中縣': 2,
#   '台北市': 3,
#   '台北縣': 4,
#   '台南市': 5,
#   '台南縣': 6,
#   '台東縣': 7,
#   '嘉義市': 8,
#   '嘉義縣': 9,
#   '基隆市': 10,
#   '宜蘭縣': 11,
#   '屏東縣': 12,
#   '彰化縣': 13,
#   '新北市': 14,
#   '新竹市': 15,
#   '新竹縣': 16,
#   '桃園市': 17,
#   '桃園縣': 18,
#   '花蓮縣': 19,
#   '苗栗縣': 20,
#   '金門縣': 21,
#   '雲林縣': 22,
#   '高雄市': 23,
#   '高雄縣': 24},
#  'CASEBASE2_NOFINRPT': {'N': 0, 'Y': 1},
#  'CASEBASE_RANK': {'A': 0, 'B': 1, 'B+': 2, 'B-': 3, 'C': 4},
#  'CASEBASE2_BILL2': {'N': 0, 'S': 1, 'Y': 2}}

# %%
cat_list = {i:list(X_M[i].unique()) for i in categorical_columns}

# %%
## IV 規則
FS_IV, FS_IV_Table = FeaturesSelection_IV(X_M, y_M)
# FileName = 'FeaturesSelection_IV.csv'
# FS_IV_Table.to_csv(FileName, index = False)

# %% [markdown]
# # 開始跑模型

# %%
from Eric_utilites.Eric_Machinelearning import *

# %run Eric_utilites/Eric_Machinelearning

# %%
### 這裡要 function 化 ###
# idx_train = X_M.index.get_level_values('CASE_ID').str[0:2] < test_year
# idx_test = X_M.index.get_level_values('CASE_ID').str[0:2] >= test_year

# %%
## ML 變數區
Model_summary = pd.DataFrame()
test_size = 0.2
col_stratify = ['CASE_Y','CASE_M']

metric = ['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2']
kfold = 10

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score


X_train, X_test, y_train, y_test = train_test_split(X_M, 
                                                    y_M, 
                                                    test_size=test_size, 
                                                    random_state=42, 
                                                    stratify=X_M[col_stratify])

y_mean = y_train.mean()
y_std = y_test.std()



len(X_M)
len(X_train)
len(X_test)
X_train.shape
# Out:
# 67539
# 54031
# 13508
# (54031, 154)

# %%
def f_PrePro(lr, categorical_columns, numerical_columns, cat_list,degree=1):
    from sklearn.impute import SimpleImputer
    from sklearn.inspection import permutation_importance
    from sklearn.compose import ColumnTransformer
    from sklearn.pipeline import Pipeline
    from sklearn.preprocessing import OneHotEncoder, StandardScaler, Normalizer
    
    from sklearn.preprocessing import PolynomialFeatures
    
    categorical_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    
    ('onehot', OneHotEncoder(categories = cat_list,handle_unknown='ignore',sparse=False))
    ])
    
    numerical_pipe = Pipeline([
        ('imputer', SimpleImputer(strategy='median')),
        ('standardize',StandardScaler())
    ])

    preprocessing = ColumnTransformer(
        [('cat', categorical_pipe,categorical_columns),
         ('num', numerical_pipe,numerical_columns)])

    clf = Pipeline([
        ('preprocess', preprocessing),
        ('poly',PolynomialFeatures(degree=degree,include_bias=False)),
        ('DecisionTreeRegressor', lr)
    ])
    return clf


def display_scores(scores):
    print("\nScores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std(),'\n')

# %%
## 按照時間均勻挑
## 產業別均勻挑
## 考慮可以「分層抽樣」的變數
## 根據真正有拿來建模的 DATA 的比例進行抽樣 train and test (hands-on chapter 2)

# %%
## DecisionTreeRegressor 決策樹回歸

from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
# col_y = ['Y_OPERATE1','CASEBASE1_GPY1']
# X = Data_final.drop(columns = col_y)
# y = Data_final[col_y[0]]

# %run Eric_utilites/Eric_Machinelearning



dtr = f_PrePro(DecisionTreeRegressor(max_depth=40,min_samples_leaf=10 ),
               categorical_columns, 
               numerical_columns,
               list(cat_list.values()),
               1)

metric_dtr , dtr = f_ModelOutCome_agg('DecisionTreeRegressor_1', dtr, X_train, y_train, X_test, y_test, kfold, metric)

f_PlotFS(dtr, numerical_columns, categorical_columns)


Model_summary = Model_summary.append(metric_dtr)
# Out:
#         fit_time  score_time  mean_squared_error  mean_absolute_error  \
# count  10.000000   10.000000           10.000000            10.000000
# mean   65.239180    0.460393            0.014136             0.019369
# std     0.655038    0.060254            0.003319             0.000833
# min    63.886990    0.395578            0.009713             0.018472
# 25%    65.093048    0.415136            0.011591             0.018868
# 50%    65.377680    0.465508            0.013956             0.019122
# 75%    65.608132    0.482725            0.016568             0.019875
# max    66.177166    0.596577            0.019216             0.021048
#
#               r2
# count  10.000000
# mean    0.985578
# std     0.003741
# min     0.980076
# 25%     0.983096
# 50%     0.985241
# 75%     0.988305
# max     0.991837
# DecisionTreeRegressor_1
# MSE train: 0.010, test: 0.015
# MAE train: 0.014, test: 0.019
# R^2 train: 0.990, test: 0.988
#                      Model  CV_MSE_mean  CV_MSE_std  CV_MAE_mean  CV_MAE_std  \
# 0  DecisionTreeRegressor_1     0.014136    0.003319     0.019369    0.000833
#
#    CV_r2_mean  CV_r2_std  MSE_train  MSE_test  MAE_train  MAE_test  \
# 0    0.985578   0.003741   0.009937  0.015485    0.01435  0.019009
#
#    R_square_train  R_square_test
# 0        0.990063       0.987736
# 1

# %%
## 線性迴歸分析
from sklearn.linear_model import LinearRegression

# %run Eric_utilites/Eric_Machinelearning


lr = f_PrePro(LinearRegression(),
               categorical_columns, 
               numerical_columns,
               list(cat_list.values()),
               1)


metric_lr , lr = f_ModelOutCome_agg('LinearRegression_1', lr, X_train, y_train, X_test, y_test, kfold, metric)

# f_PlotFS(lr, numerical_columns, categorical_columns)


Model_summary = Model_summary.append(metric_lr)
# Out:
#         fit_time  score_time  mean_squared_error  mean_absolute_error  \
# count  10.000000   10.000000           10.000000            10.000000
# mean   42.717715    0.247120           59.556921             0.378709
# std     1.616644    0.046337          187.280803             0.099161
# min    40.659209    0.205631            0.280139             0.340113
# 25%    41.553569    0.214501            0.300674             0.346539
# 50%    42.698966    0.237176            0.306955             0.348075
# 75%    43.741663    0.248203            0.310561             0.350106
# max    44.977521    0.356574          592.567369             0.660778
#
#                r2
# count   10.000000
# mean   -59.488516
# std    190.223145
# min   -600.873004
# 25%      0.685496
# 50%      0.696515
# 75%      0.706339
# max      0.713805
# LinearRegression_1
# MSE train: 0.291, test: 0.301
# MAE train: 0.341, test: 0.346
# R^2 train: 0.709, test: 0.705
#                 Model  CV_MSE_mean  CV_MSE_50%  CV_MSE_std  CV_MAE_mean  \
# 0  LinearRegression_1    59.556921    0.306955  187.280803     0.378709
#
#    CV_MAE_50%  CV_MAE_std  CV_r2_mean  CV_r2_50%   CV_r2_std  MSE_train  \
# 0    0.348075    0.099161  -59.488516   0.696515  190.223145   0.291002
#
#    MSE_test  MAE_train  MAE_test  R_square_train  R_square_test
# 0  0.301006   0.341098  0.345906        0.708993       0.705266

# %%
## 極限樹
from sklearn.ensemble import ExtraTreesRegressor 


for i in range(1,2):
    etr = f_PrePro(ExtraTreesRegressor(n_estimators = 10,max_depth = 40,min_samples_leaf =10,random_state=42,n_jobs=-1),
                   categorical_columns, 
                   numerical_columns,
                   list(cat_list.values()),
                   i)
    metric_etr , etr = f_ModelOutCome_agg('ExtraTreesRegressor_' + str(i), etr, X_train, y_train, X_test, y_test, kfold, metric)

    f_PlotFS(etr, numerical_columns, categorical_columns)


    Model_summary = Model_summary.append(metric_etr)
# Out:
#         fit_time  score_time  mean_squared_error  mean_absolute_error  \
# count  10.000000   10.000000           10.000000            10.000000
# mean   64.943599    0.384632            0.100445             0.158252
# std    12.742561    0.071034            0.007511             0.003411
# min    40.305097    0.264658            0.091254             0.155025
# 25%    69.453873    0.364773            0.095508             0.155970
# 50%    71.132688    0.388480            0.097875             0.157748
# 75%    71.274197    0.441067            0.103702             0.158143
# max    72.317875    0.473957            0.113213             0.164855
#
#               r2
# count  10.000000
# mean    0.899505
# std     0.007406
# min     0.885600
# 25%     0.895570
# 50%     0.902147
# 75%     0.904576
# max     0.907335
# ExtraTreesRegressor_1
# MSE train: 0.052, test: 0.099
# MAE train: 0.112, test: 0.156
# R^2 train: 0.948, test: 0.903
#                    Model  CV_MSE_mean  CV_MSE_50%  CV_MSE_std  CV_MAE_mean  \
# 0  ExtraTreesRegressor_1     0.100445    0.097875    0.007511     0.158252
#
#    CV_MAE_50%  CV_MAE_std  CV_r2_mean  CV_r2_50%  CV_r2_std  MSE_train  \
# 0    0.157748    0.003411    0.899505   0.902147   0.007406     0.0523
#
#    MSE_test  MAE_train  MAE_test  R_square_train  R_square_test
# 0  0.099034   0.112152  0.156433        0.947699       0.903029
# 1

# %%
# 隨機森林

from sklearn.ensemble import RandomForestRegressor 


for i in range(1,2):
    rfr = f_PrePro(RandomForestRegressor(n_estimators = 10, max_depth = 40,min_samples_leaf =10,random_state=42,n_jobs=-1),
                   categorical_columns, 
                   numerical_columns,
                   list(cat_list.values()),
                   i)
    
    metric_rfr, rfr = f_ModelOutCome_agg('RandomForestRegressor_' + str(i), rfr, X_train, y_train, X_test, y_test, kfold, metric)

    f_PlotFS(rfr, numerical_columns, categorical_columns)


    Model_summary = Model_summary.append(metric_rfr)
# Out:
#         fit_time  score_time  mean_squared_error  mean_absolute_error  \
# count  10.000000   10.000000           10.000000            10.000000
# mean   48.054417    0.352224            0.111939             0.166512
# std     5.109061    0.070908            0.004953             0.002464
# min    34.538063    0.265219            0.103363             0.161762
# 25%    48.200387    0.292462            0.108869             0.165601
# 50%    50.278670    0.343720            0.112386             0.166123
# 75%    50.610415    0.407026            0.114561             0.168292
# max    50.918771    0.462202            0.118916             0.170089
#
#               r2
# count  10.000000
# mean    0.887992
# std     0.005096
# min     0.880084
# 25%     0.884357
# 50%     0.887645
# 75%     0.892160
# max     0.896005
# RandomForestRegressor_1
# MSE train: 0.062, test: 0.113
# MAE train: 0.120, test: 0.165
# R^2 train: 0.938, test: 0.889
#                      Model  CV_MSE_mean  CV_MSE_50%  CV_MSE_std  CV_MAE_mean  \
# 0  RandomForestRegressor_1     0.111939    0.112386    0.004953     0.166512
#
#    CV_MAE_50%  CV_MAE_std  CV_r2_mean  CV_r2_50%  CV_r2_std  MSE_train  \
# 0    0.166123    0.002464    0.887992   0.887645   0.005096   0.062101
#
#    MSE_test  MAE_train  MAE_test  R_square_train  R_square_test
# 0  0.113391    0.12017  0.164783        0.937898       0.888972
# 1

# %%
## LinearSVR

from sklearn.svm import SVR

for ker_i in ['linear']: #, 'poly', 'rbf', 'sigmoid', 'precomputed']:

    svr = SVR(kernel=ker_i, degree=2, C=100, epsilon=0.1)
    
    
    svr = f_PrePro(svr,
                   categorical_columns, 
                   numerical_columns,
                   list(cat_list.values()))
    
    
    metric_svr, svr = f_ModelOutCome_agg('SVR_' + ker_i, svr, X_train, y_train, X_test, y_test, kfold, metric)

    #f_PlotFS(svr, numerical_columns, categorical_columns)


    Model_summary = Model_summary.append(metric_svr)

# %%
Model_summary

# %% [markdown]
# # Feature Selection

# %%
## 考慮重要參數
n = 10## 選取 IV method 前一百個變數
col_feature1 = FS_IV['index'][:n].to_list()

for i in range(1,3):
    categorical_columns_fs = list(set(categorical_columns) & set(col_feature1))
    numerical_columns_fs = list(set(numerical_columns) & set(col_feature1))
    
    cat_list_FS = [ cat_list[i] for i in categorical_columns_fs]
    
    X_train_FS = X_train[col_feature1]
    X_test_FS = X_test[col_feature1]
    
    ## linear 
    lr_fs = f_PrePro(LinearRegression(),
                   categorical_columns_fs, 
                   numerical_columns_fs,
                   cat_list_FS,
                   i)
    
    metric_lr_fs, lr_fs = f_ModelOutCome_agg('LinearRegression_FS_' + str(i), lr_fs, X_train_FS, y_train, X_test_FS, y_test, kfold, metric)
    Model_summary = Model_summary.append(metric_lr_fs)
    
    
    ## decision tree
    dtr_fs = f_PrePro(DecisionTreeRegressor(max_depth=40,min_samples_leaf=10 ),
                   categorical_columns_fs, 
                   categorical_columns_fs,
                   cat_list_FS,
                   i)
    
    metric_dtr_fs, dtr_fs = f_ModelOutCome_agg('DecisionTreeRegressor_FS_' + str(i), dtr_fs, X_train_FS, y_train, X_test_FS, y_test, kfold, metric)
    Model_summary = Model_summary.append(metric_dtr_fs)
    
    
    ## extra tree
    etr_fs = f_PrePro(ExtraTreesRegressor(n_estimators = 10, max_depth = 40,min_samples_leaf =10,random_state=42, n_jobs = -1),
                   categorical_columns_fs, 
                   numerical_columns_fs,
                   cat_list_FS,
                   i)
    
    metric_etr_fs, etr_fs = f_ModelOutCome_agg('ExtraTreeRegressor_FS_' + str(i), etr_fs, X_train_FS, y_train, X_test_FS, y_test, kfold, metric)
    Model_summary = Model_summary.append(metric_etr_fs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-1895e85c8e1c> in <module>
#      13
#      14     ## linear
# ---> 15     lr_fs = f_PrePro(LinearRegression(),
#      16                    categorical_columns_fs,
#      17                    numerical_columns_fs,
#
# NameError: name 'LinearRegression' is not defined

# %%
Model_summary
# Out:
#                      Model   CV_MSE_mean  CV_MSE_50%    CV_MSE_std  \
# 0  DecisionTreeRegressor_1  1.515173e-01    0.150513  8.834368e-03
# 0       LinearRegression_1  5.955692e+01    0.306955  1.872808e+02
# 0    ExtraTreesRegressor_1  1.004449e-01    0.097875  7.510800e-03
# 0  RandomForestRegressor_1  1.119390e-01    0.112386  4.953366e-03
# 0       LinearRegression_1  7.292319e+01    0.347325  2.295156e+02
# 0  DecisionTreeRegressor_1  3.333116e-01    0.334281  1.264978e-02
# 0       LinearRegression_1  7.292319e+01    0.347325  2.295156e+02
# 0  DecisionTreeRegressor_1  3.331504e-01    0.334204  1.252322e-02
# 0     ExtraTreeRegressor_1  1.435881e-01    0.143268  7.480976e-03
# 0       LinearRegression_2  2.945275e+09    0.580889  9.313779e+09
# 0  DecisionTreeRegressor_2  3.291718e-01    0.328774  1.065260e-02
# 0     ExtraTreeRegressor_2  1.267660e-01    0.123830  8.251035e-03
#
#    CV_MAE_mean  CV_MAE_50%  CV_MAE_std    CV_r2_mean  CV_r2_50%     CV_r2_std  \
# 0     0.187201    0.186447    0.004193  8.484382e-01   0.846844  7.926566e-03
# 0     0.378709    0.348075    0.099161 -5.948852e+01   0.696515  1.902231e+02
# 0     0.158252    0.157748    0.003411  8.995054e-01   0.902147  7.405908e-03
# 0     0.166512    0.166123    0.002464  8.879919e-01   0.887645  5.096040e-03
# 0     0.398333    0.364732    0.109140 -7.306323e+01   0.654711  2.331217e+02
# 0     0.330040    0.330546    0.004772  6.666678e-01   0.665228  5.858710e-03
# 0     0.398333    0.364732    0.109140 -7.306323e+01   0.654711  2.331217e+02
# 0     0.329994    0.330690    0.004744  6.668240e-01   0.665367  5.911475e-03
# 0     0.196913    0.198005    0.004542  8.563082e-01   0.856823  7.908095e-03
# 0   227.167188    0.272302  717.508312 -2.991528e+09   0.417641  9.460042e+09
# 0     0.327095    0.327565    0.004790  6.707529e-01   0.670662  5.620200e-03
# 0     0.184563    0.183644    0.004024  8.731370e-01   0.873695  8.517000e-03
#
#    MSE_train  MSE_test  MAE_train  MAE_test  R_square_train  R_square_test
# 0   0.062849  0.145623   0.118901  0.181159        0.937150       0.857412
# 0   0.291002  0.301006   0.341098  0.345906        0.708993       0.705266
# 0   0.052300  0.099034   0.112152  0.156433        0.947699       0.903029
# 0   0.062101  0.113391   0.120170  0.164783        0.937898       0.888972
# 0   0.333783  0.349944   0.358924  0.366785        0.666212       0.657349
# 0   0.304935  0.340736   0.315429  0.333441        0.695060       0.666364
# 0   0.333783  0.349944   0.358924  0.366785        0.666212       0.657349
# 0   0.304935  0.341053   0.315429  0.333527        0.695060       0.666054
# 0   0.104769  0.138570   0.169186  0.193226        0.895229       0.864317
# 0   0.144272  0.360057   0.206017  0.263641        0.855725       0.647446
# 0   0.297632  0.333674   0.311701  0.329786        0.702363       0.673279
# 0   0.083349  0.125272   0.149763  0.181660        0.916650       0.877338

# %%
Model_summary.to_csv('with_opy2.csv')

# %%
# ### 對 y 進行轉換
# # 線性迴歸分析


# from sklearn.linear_model import LinearRegression
# from sklearn.compose import TransformedTargetRegressor
# from sklearn.preprocessing import StandardScaler



# func = lambda x: np.log(abs(x+1)) * np.sign(x)
# inverse_func = lambda x : (np.exp(abs(x)) - 1) * np.sign(x)

# reg = TransformedTargetRegressor(regressor=LinearRegression(),
#                                  transformer= StandardScaler())
#                                  #func=func, inverse_func=inverse_func)

# lr = f_PrePro(reg,
#                categorical_columns, 
#                numerical_columns)

# ## Cross_val_score
# lin_scores = cross_val_score(lr, X_train, y_train,
#                              scoring="neg_mean_squared_error", cv=10)
# lin_rmse_scores = np.sqrt(-lin_scores)
# display_scores(lin_rmse_scores)

# lr = f_ModelOutcome(lr, X_train, y_train, X_test, y_test)

# %%
# ## LinearSVR
# from sklearn.svm import SVR

# reg_svr = SVR(kernel="poly", degree=2, C=100, epsilon=0.1)

# lr = f_PrePro(reg_svr,
#               categorical_columns, 
#               numerical_columns)

# lr = f_ModelOutcome(lr, X_train, y_train, X_test, y_test)

# %%
# # Importing module and initializing setup
# from pycaret.regression import *

# clf1 = setup(data = Data_M, 
#              target = 'Y_OPERATE1',
#              normalize = True,
#              normalize_method='zscore',
#              feature_selection= True,
#              ignore_features = ['CASEBASE1_GPY1'],
#              categorical_features =['CASEBASE_BUSTYPE_4'] + [  i + '_num'for i in col_mapping.keys()],
#              numeric_features = [],
#              n_jobs=-1)
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
#     #T_2909d436_ee97_11ea_98e3_17314e362de3row4_col1 {
#             background-color:  yellow;
#         }    #T_2909d436_ee97_11ea_98e3_17314e362de3row15_col1 {
#             background-color:  yellow;
#         }    #T_2909d436_ee97_11ea_98e3_17314e362de3row37_col1 {
#             background-color:  yellow;
#         }</style><table id="T_2909d436_ee97_11ea_98e3_17314e362de3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row0_col1" class="data row0 col1" >3620</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row1_col0" class="data row1 col0" >Transform Target </td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row2_col0" class="data row2 col0" >Transform Target Method</td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row3_col1" class="data row3 col1" >(127747, 102)</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row4_col1" class="data row4 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row5_col1" class="data row5 col1" >64</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row6_col1" class="data row6 col1" >37</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row10_col1" class="data row10 col1" >(56208, 102)</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row11_col1" class="data row11 col1" >(39345, 482)</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row12_col1" class="data row12 col1" >(16863, 482)</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row15_col1" class="data row15 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row16_col1" class="data row16 col1" >zscore</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e362de3level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_2909d436_ee97_11ea_98e3_17314e362de3row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2909d436_ee97_11ea_98e3_17314e36

# %%
# best = compare_models()
# Out:
# <style  type="text/css" >
#     #T_34831460_eeb7_11ea_98e3_17314e362de3 th {
#           text-align: left;
#     }    #T_34831460_eeb7_11ea_98e3_17314e362de3row0_col0 {
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row0_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row1_col0 {
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row1_col4 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row1_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row2_col0 {
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row2_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row2_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row3_col0 {
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row3_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row4_col0 {
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row4_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row5_col0 {
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row5_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row6_col0 {
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row6_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row7_col0 {
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row7_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row7_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row8_col0 {
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row8_col4 {
#             : ;
#             text-align:  left;
#         }    #T_34831460_eeb7_11ea_98e3_17314e362de3row8_col5 {
